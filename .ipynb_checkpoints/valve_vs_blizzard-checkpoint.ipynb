# %% [markdown]
# ##### Goal: Find out which game company has a higher overall rating (Valve vs Blizzard)

# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
valve_url = 'https://en.wikipedia.org/wiki/List_of_Valve_games'
blizzard_url = 'https://en.wikipedia.org/wiki/List_of_Blizzard_Entertainment_games'

valve_html = requests.get(valve_url)
blizzard_html = requests.get(blizzard_url)

# %%
soup = bs(valve_html.content)

contents = soup.prettify()

#print(contents)

# %%
games = soup.select('.wikitable i a')
game_path = games[0]['href']

#game_path

# %%
def get_game_links(url):
    html = requests.get(url)
    soup = bs(html.content)
    games = soup.select('.wikitable i a')
    games = soup.select('.wikitable .fn i a')
    game_links = []
    base_path = 'https://en.wikipedia.org'

    for game in games:
        # subdirectory example: "/wiki/Half-Life_(video_game)"
        game_subdirectory = game['href']
        path = base_path + game_subdirectory
        game_links.append(path)
    
    return game_links

#get_game_links('https://en.wikipedia.org/wiki/List_of_Valve_games')

# %%
import re

def remove_ref(contents):
    # regular expression to find all matches with format [c] where c is any character eg. [a] or [1]
    reference = r'\[.\]'
    
    if type(contents) == str:
        matches = re.findall(reference, contents)
        # for each match, remove it from the string
        for match in matches:
            contents = contents.replace(match, '')
        # final remove whitespace that might've been between ref n text
        contents = contents.strip()
        return contents
    
    elif type(contents) == list:
        contents_list = []
        for my_string in contents:
            matches = re.findall(reference, my_string)
            for match in matches:
                my_string = my_string.replace(match, '')
                # final remove whitespace that might've been between ref n text
                my_string = my_string.strip()
            contents_list.append(my_string)
        return contents_list

# %%
def get_row_contents(row):
    # to handle releases
    # strip=True to remove whitespace chars (\n, xa0, etc)
    if row.select('li ul li'):
        return [li.get_text('', strip=True) for li in row.select('li ul li')]
    elif row.find('li'):
        return [li.get_text('', strip=True) for li in row.find_all('li')]
    elif row.find('br'):
        # stripped strings strips out whitespace chars
        return [text for text in row.find('td').stripped_strings]
    elif "," in row.get_text():
        return [text.strip() for text in row.find('td', class_='infobox-data').get_text().split(',')]
    else:  
        #print(row)
        return row.find('td', class_='infobox-data').get_text()

# %%
import re

def standardise_date(date):
    # other date format
    uncommon_date_re = r'\d+[ ][A-Za-z]+[ ]\d+'
    if re.search(uncommon_date_re, date):
        # first split string to list
        # eg. 15 June 2005 to [15, 'June', 2005]
        split_date = date.split()
        # make date string like this: June 15, 2005
        new_date = f'{split_date[1]} {split_date[0]}, {split_date[2]}'
        return new_date
    else:
        return date

standardise_date('15 June 2005')
# Out:
# 'June 15, 2005'

# %%
from datetime import datetime

def convert_to_datetime(date_str):
    date_format = '%B %d, %Y'
    date = datetime.strptime(date_str, date_format)
    return date

convert_to_datetime('June 15, 2005')
# Out:
# datetime.datetime(2005, 6, 15, 0, 0)

# %%
import re

def get_release_date(row):
    if row.select('ul li'):
        contents = [li.get_text('', strip=True) for li in row.select('ul li')]
        #print('in ul li if statement')
    else:
        contents = row.find('td', class_='infobox-data').get_text()
        #print('in everything else')
    #print(contents)
    # June 15, 2005 or 15 June 2005 
    date_re = r'([A-Za-z]+[ ]\d+,[ ]\d+)|(\d+[ ][A-Za-z]+[ ]\d+)'
    
    if type(contents) == str:
        match = re.search(date_re, contents)
        date = match.group()
        standardised_date = standardise_date(date)
        datetime_obj = convert_to_datetime(standardised_date)
        return datetime_obj
    elif type(contents) == list:
        for i, item in enumerate(contents):
            match = re.search(date_re, item)
            #print(i, match)
            if (match != None):
                date = match.group()
                standardised_date = standardise_date(date)
                datetime_obj = convert_to_datetime(standardised_date)
                return datetime_obj
        return None

#get_release_date(['Microsoft Windows', '29 November 2006', 'Mac OS X', '23 September 2010', 'Linux', '5 June 2013'])

# %%
import re

def name_to_link(name):
    # matches when a char is not a-zA-Z or 0-9 or "_"
    alphanumeric_re = r'\W'
    
    name = name.lower()
    name = name.replace(' ', '_')
    name = name.replace('-', '_')
    # remove matches of non alphanumeric or "_"
    name = re.sub(alphanumeric_re, '', name)
    name = name.replace('_', '-')
    
    return name

#print(name_to_link('Garry\'s Mod'))
#print(name_to_link('Half life 2: Lost Coast'))

# %%
def get_game_rating(name):
    # change name to link format
    # eg. https://www.metacritic.com/game/pc/garrys-mod, https://www.metacritic.com/game/pc/half-life
    name = name_to_link(name)
    url = f'https://www.metacritic.com/game/pc/{name}'
    #print(url)

    user_agent = {'User-agent': 'Mozilla/5.0'}
    response = requests.get(url, headers = user_agent)
    soup = bs(response.content)
    
    metascore = soup.find('span', itemprop='ratingValue')
    if metascore is not None:
        metascore_str = metascore.get_text()
    else:
        metascore_str = 'N/A'
        
        
    userscore = soup.select('.score_summary .metascore_anchor .metascore_w.user')
    # by default returns empty list
    if len(userscore) > 0:
        userscore_str = userscore[0].get_text()
    else:
        userscore_str = 'N/A'
    
    return metascore_str, userscore_str

#for name in names:
    #print(get_game_rating(name))

# %%
# deal with random (text) and '' whitespaces at the end
def remove_random_contents(contents):
    # to match format (Japan something) or ':'
    random_re = r'(\(*\))|[:]'
    #print(contents)
    if type(contents) == list:
        for item in contents:
            # if find item in format (Japan something) or ':' or empty string ''
            if re.search(random_re, item) or len(item) == 0:
                # remove that item from contents
                contents.remove(item)
    return contents

# %%
def get_info_box(url):
    game_html = requests.get(url)
    game_soup = bs(game_html.content)
    base_path = 'https://en.wikipedia.org'
    
    info_box = game_soup.find('table', class_='infobox')
    info_rows = info_box.find_all('tr')
    
    game_info = {}
    
    for i, row in enumerate(info_rows):
        # get title from infobox
        if row.select('.infobox-above'):
            game_info['Name'] = row.find('th').get_text()
            # handling really rare edge case with different naming
            if game_info['Name'] == 'Hearthstone':
                game_info['Name'] = 'Hearthstone: Heroes of Warcraft'
        # get image link from infobox
        elif row.select('.infobox-image'):
            image_link = base_path + row.find('a')['href']
            game_info['Image_link'] = image_link
        else:
            label = row.find('th', class_='infobox-label').get_text()
            contents = get_row_contents(row)
            contents = remove_ref(contents)
            if (label == 'Release'):
                #print(contents)
                contents = get_release_date(row)
                #print(contents)
            #print(contents)
            contents = remove_random_contents(contents)
            #print(contents)
            #print(f'Label: {label}, type: {type(contents)}')
                
            #print(contents)
            game_info[label] = contents
    
    game_info['Source'] = url
    
    metascore, userscore = get_game_rating(game_info['Name'])
    game_info['Metascore'] = metascore
    game_info['User Score'] = userscore
    
    return game_info
    
    
get_info_box('https://en.wikipedia.org/wiki/Justice_League_Task_Force_(video_game)')
# Out:
# {'Name': 'Justice League Task Force',
#  'Image_link': 'https://en.wikipedia.org/wiki/File:Justice_League_Task_Force_game_cover.jpg',
#  'Developer(s)': ['Sunsoft',
#   'Super NES',
#   'Blizzard Entertainment',
#   'Mega Drive/Genesis',
#   'Condor, Inc.'],
#  'Publisher(s)': 'Acclaim Entertainment',
#  'Composer(s)': ['Matt Uelmen', 'Glenn Stafford'],
#  'Platform(s)': ['Genesis', 'Super NES'],
#  'Release': datetime.datetime(1995, 9, 1, 0, 0),
#  'Genre(s)': 'Fighting',
#  'Mode(s)': ['Single-player', 'multiplayer'],
#  'Source': 'https://en.wikipedia.org/wiki/Justice_League_Task_Force_(video_game)',
#  'Metascore': 'N/A',
#  'User Score': 'N/A'}

# %%
def scrape_game_company(url):
    game_links = get_game_links(url)
    games_info = []
    for i, link in enumerate(game_links):
        try:
            games_info.append(get_info_box(link))
            if (i % 10 == 0):
                print(f'--Scraped {i} games--')

        except Exception as e:
            print(link)
            print(e)

    print(f'Scraping finished with {i} games')
    return games_info

# %%
valve_games = scrape_game_company(valve_url)
# Out:
# --Scraped 0 games--
# --Scraped 10 games--
# --Scraped 20 games--
# Scraping finished with 26 games

# %%
# ignore exceptions (they're games that haven't been released)
blizzard_games = scrape_game_company(blizzard_url)
# Out:
# --Scraped 0 games--
# --Scraped 10 games--
# https://en.wikipedia.org/wiki/Overwatch_2
# 'NoneType' object has no attribute 'group'
# https://en.wikipedia.org/wiki/Diablo_IV
# 'NoneType' object has no attribute 'group'
# Scraping finished with 21 games

# %%
valve_games
# Out:
# [{'Name': 'Half-Life',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_Cover_Art.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Sierra Studios',
#   'Writer(s)': 'Marc Laidlaw',
#   'Composer(s)': 'Kelly Bailey',
#   'Series': 'Half-Life',
#   'Engine': 'GoldSrc',
#   'Platform(s)': ['Windows', 'PlayStation 2', 'OS X', 'Linux'],
#   'Release': datetime.datetime(1998, 11, 19, 0, 0),
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life_(video_game)',
#   'Metascore': '96',
#   'User Score': '9.1'},
#  {'Name': 'Team Fortress Classic',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Team_Fortress_Classic_box.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': ['Sierra Studios'],
#   'Designer(s)': ['John Cook', 'Robin Walker'],
#   'Engine': 'GoldSrc',
#   'Platform(s)': ['Microsoft Windows', 'OS X', 'Linux'],
#   'Release': datetime.datetime(1999, 4, 7, 0, 0),
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Team_Fortress_Classic',
#   'Metascore': 'N/A',
#   'User Score': '7.2'},
#  {'Name': 'Counter-Strike',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Counter-Strike_Box.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': ['Sierra Studios'],
#   'Designer(s)': ['Minh Le', 'Jess Cliffe'],
#   'Series': 'Counter-Strike',
#   'Engine': 'GoldSrc',
#   'Platform(s)': ['Windows', 'Xbox', 'OS X', 'Linux'],
#   'Release': datetime.datetime(2000, 11, 9, 0, 0),
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Counter-Strike_(video_game)',
#   'Metascore': '88',
#   'User Score': '9.2'},
#  {'Name': 'Day of Defeat',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Day_of_Defeat_cover_art.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': ['Activision'],
#   'Composer(s)': 'Michael Gordon Shapiro',
#   'Engine': 'GoldSrc',
#   'Platform(s)': ['Microsoft Windows', 'OS X', 'Linux'],
#   'Release': datetime.datetime(2003, 5, 6, 0, 0),
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Day_of_Defeat',
#   'Metascore': '79',
#   'User Score': '9.0'},
#  {'Name': 'Counter-Strike: Condition Zero',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:CZbox.jpg',
#   'Developer(s)': ['Ritual Entertainment', 'Turtle Rock Studios', 'Valve'],
#   'Publisher(s)': ['Sierra Entertainment'],
#   'Series': 'Counter-Strike',
#   'Engine': 'GoldSrc',
#   'Platform(s)': ['Windows', 'OS X', 'Linux'],
#   'Release': datetime.datetime(2004, 3, 23, 0, 0),
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Counter-Strike:_Condition_Zero',
#   'Metascore': '65',
#   'User Score': '8.7'},
#  {'Name': 'Counter-Strike: Source',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Counter-Strike_Source_(box_art).jpg',
#   'Developer(s)': ['Valve', 'Turtle Rock Studios'],
#   'Publisher(s)': 'Valve',
#   'Series': 'Counter-Strike',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows', 'Mac OS X', 'Linux'],
#   'Release': datetime.datetime(2004, 10, 7, 0, 0),
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Counter-Strike:_Source',
#   'Metascore': '88',
#   'User Score': '8.9'},
#  {'Name': 'Half-Life 2',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_2_cover.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': ['Valve'],
#   'Artist(s)': 'Viktor Antonov',
#   'Writer(s)': 'Marc Laidlaw',
#   'Composer(s)': 'Kelly Bailey',
#   'Series': 'Half-Life',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows',
#    'Xbox',
#    'Xbox 360',
#    'PlayStation 3',
#    'Mac OS X',
#    'Linux',
#    'Android'],
#   'Release': datetime.datetime(2004, 11, 16, 0, 0),
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life_2',
#   'Metascore': '96',
#   'User Score': '9.2'},
#  {'Name': 'Half-Life 2: Deathmatch',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_2_Deathmatch_cover.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Series': 'Half-Life',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows', 'Mac OS X', 'Linux'],
#   'Release': datetime.datetime(2004, 11, 30, 0, 0),
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life_2:_Deathmatch',
#   'Metascore': 'N/A',
#   'User Score': '7.3'},
#  {'Name': 'Day of Defeat: Source',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:DODSourceCover.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Composer(s)': 'Dan Haigh',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows', 'Mac OS X', 'Linux'],
#   'Release': datetime.datetime(2005, 9, 26, 0, 0),
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Day_of_Defeat:_Source',
#   'Metascore': '80',
#   'User Score': '9.0'},
#  {'Name': 'Half-Life 2: Lost Coast',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_2_Lost_Coast_header.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Series': 'Half-Life',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows', 'OS X', 'Linux'],
#   'Release': datetime.datetime(2005, 10, 27, 0, 0),
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life_2:_Lost_Coast',
#   'Metascore': 'N/A',
#   'User Score': '7.9'},
#  {'Name': 'Half-Life 2: Episode One',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_2_-_Episode_One.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Writer(s)': ['Erik Wolpaw', 'Chet Faliszek'],
#   'Composer(s)': 'Kelly Bailey',
#   'Series': 'Half-Life',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows',
#    'Xbox 360',
#    'PlayStation 3',
#    'Mac OS X',
#    'Linux',
#    'Android'],
#   'Release': datetime.datetime(2006, 6, 1, 0, 0),
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life_2:_Episode_One',
#   'Metascore': '87',
#   'User Score': '8.7'},
#  {'Name': 'Half-Life 2: Episode Two',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_2_Episode_Two_title.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Writer(s)': ['Erik Wolpaw', 'Chet Faliszek'],
#   'Composer(s)': 'Kelly Bailey',
#   'Series': 'Half-Life',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows', 'PlayStation 3', 'Xbox 360', 'Mac OS X', 'Linux'],
#   'Release': datetime.datetime(2007, 10, 10, 0, 0),
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life_2:_Episode_Two',
#   'Metascore': '90',
#   'User Score': '9.2'},
#  {'Name': 'Portal',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Portal_standalonebox.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': ['Valve'],
#   'Designer(s)': 'Kim Swift',
#   'Writer(s)': ['Erik Wolpaw', 'Chet Faliszek'],
#   'Composer(s)': ['Kelly Bailey', 'Mike Morasky'],
#   'Series': 'Portal',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows',
#    'PlayStation 3',
#    'Xbox 360',
#    'Mac OS X',
#    'Linux',
#    'Android',
#    'Nintendo Switch'],
#   'Release': datetime.datetime(2007, 10, 10, 0, 0),
#   'Genre(s)': 'Puzzle-platform',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Portal_(video_game)',
#   'Metascore': '90',
#   'User Score': '9.2'},
#  {'Name': 'Team Fortress 2',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Tf2_standalonebox.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Designer(s)': ['John Cook', 'Robin Walker'],
#   'Composer(s)': 'Mike Morasky',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows', 'Xbox 360', 'PlayStation 3', 'Mac OS X', 'Linux'],
#   'Release': datetime.datetime(2007, 10, 10, 0, 0),
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Team_Fortress_2',
#   'Metascore': '92',
#   'User Score': '9.0'},
#  {'Name': 'The Orange Box',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Hltob-win-cover.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows',
#    'Xbox 360',
#    'PlayStation 3',
#    'Mac OS X',
#    'Linux'],
#   'Release': datetime.datetime(2007, 10, 10, 0, 0),
#   'Genre(s)': 'Various',
#   'Mode(s)': ['Single player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/The_Orange_Box',
#   'Metascore': '96',
#   'User Score': '9.1'},
#  {'Name': 'Left 4 Dead',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Left4Dead_Windows_cover.jpg',
#   'Developer(s)': 'Valve South',
#   'Publisher(s)': 'Valve',
#   'Designer(s)': 'Mike Booth',
#   'Writer(s)': 'Chet Faliszek',
#   'Composer(s)': 'Mike Morasky',
#   'Series': 'Left 4 Dead',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows', 'Xbox 360', 'Mac OS X'],
#   'Release': datetime.datetime(2008, 11, 17, 0, 0),
#   'Genre(s)': ['First-person shooter', 'survival horror'],
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Left_4_Dead',
#   'Metascore': '89',
#   'User Score': '9.0'},
#  {'Name': 'Left 4 Dead 2',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Left4Dead2.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Designer(s)': 'Michael Booth',
#   'Writer(s)': 'Chet Faliszek',
#   'Composer(s)': 'Mike Morasky',
#   'Series': 'Left 4 Dead',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows', 'Xbox 360', 'Mac OS X', 'Linux'],
#   'Release': datetime.datetime(2009, 11, 17, 0, 0),
#   'Genre(s)': ['First-person shooter', 'survival horror'],
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Left_4_Dead_2',
#   'Metascore': '89',
#   'User Score': '8.4'},
#  {'Name': 'Alien Swarm',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Alien_Swarm_Header.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Composer(s)': 'Mike Morasky',
#   'Engine': 'Source',
#   'Platform(s)': 'Microsoft Windows',
#   'Release': datetime.datetime(2010, 7, 19, 0, 0),
#   'Genre(s)': 'Top-down shooter',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Alien_Swarm',
#   'Metascore': '77',
#   'User Score': '8.2'},
#  {'Name': 'Portal 2',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Portal2cover.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Director(s)': 'Joshua Weier',
#   'Producer(s)': 'Gabe Newell',
#   'Artist(s)': ['Jeremy Bennett', 'Randy Lundeen'],
#   'Writer(s)': ['Erik Wolpaw', 'Jay Pinkerton', 'Chet Faliszek'],
#   'Composer(s)': 'Mike Morasky',
#   'Series': 'Portal',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows',
#    'Mac OS X',
#    'Linux',
#    'PlayStation 3',
#    'Xbox 360',
#    'Nintendo Switch'],
#   'Release': datetime.datetime(2011, 4, 18, 0, 0),
#   'Genre(s)': 'Puzzle-platform',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Portal_2',
#   'Metascore': '95',
#   'User Score': '9.1'},
#  {'Name': 'Counter-Strike: Global Offensive',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:CSGOcoverMarch2020.jpg',
#   'Developer(s)': ['Valve', 'Hidden Path Entertainment'],
#   'Publisher(s)': 'Valve',
#   'Composer(s)': 'Mike Morasky',
#   'Series': 'Counter-Strike',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows',
#    'macOS',
#    'Linux',
#    'PlayStation 3',
#    'Xbox 360'],
#   'Release': datetime.datetime(2012, 8, 21, 0, 0),
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Counter-Strike:_Global_Offensive',
#   'Metascore': '83',
#   'User Score': '7.3'},
#  {'Name': 'Dota 2',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Dota_2_(Steam_2019).jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Designer(s)': 'IceFrog',
#   'Writer(s)': ['Marc Laidlaw', 'Ted Kosmatka', 'Kris Katz'],
#   'Composer(s)': ['Jason Hayes', 'Tim Larkin'],
#   'Series': 'Dota',
#   'Engine': 'Source 2',
#   'Platform(s)': ['Microsoft Windows', 'Linux', 'OS X'],
#   'Release': datetime.datetime(2013, 7, 9, 0, 0),
#   'Genre(s)': 'MOBA',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Dota_2',
#   'Metascore': '90',
#   'User Score': '6.5'},
#  {'Name': 'The Lab',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:The_lab_logo.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Series': 'Portal',
#   'Engine': ['Unity'],
#   'Platform(s)': 'Windows',
#   'Release': datetime.datetime(2016, 4, 5, 0, 0),
#   'Genre(s)': 'Action',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/The_Lab_(video_game)',
#   'Metascore': 'N/A',
#   'User Score': '8.5'},
#  {'Name': 'Artifact',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Artifact_poster.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Director(s)': 'Brandon Reinhart',
#   'Designer(s)': 'Richard Garfield',
#   'Programmer(s)': ['Brad Muir', 'Jeep Barnett', 'Bruno Carlucci'],
#   'Writer(s)': 'Steve Jaros',
#   'Composer(s)': 'Tim Larkin',
#   'Series': 'Dota',
#   'Engine': 'Source 2',
#   'Platform(s)': ['Windows', 'macOS', 'Linux'],
#   'Release': datetime.datetime(2018, 11, 28, 0, 0),
#   'Genre(s)': 'Digital collectible card game',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Artifact_(video_game)',
#   'Metascore': '76',
#   'User Score': '2.2'},
#  {'Name': 'Dota Underlords',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Dota_Underlords_steam.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Series': 'Dota',
#   'Engine': 'Source 2',
#   'Platform(s)': ['Android', 'iOS', 'macOS', 'Microsoft Windows', 'Linux'],
#   'Release': datetime.datetime(2020, 2, 25, 0, 0),
#   'Genre(s)': 'Auto battler',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Dota_Underlords',
#   'Metascore': 'N/A',
#   'User Score': '7.4'},
#  {'Name': 'Half-Life: Alyx',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_Alyx_Cover_Art.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Writer(s)': ['Jay Pinkerton', 'Sean Vanaman', 'Erik Wolpaw', 'Jake Rodkin'],
#   'Composer(s)': 'Mike Morasky',
#   'Series': 'Half-Life',
#   'Engine': 'Source 2',
#   'Platform(s)': ['Windows', 'Linux'],
#   'Release': datetime.datetime(2020, 3, 23, 0, 0),
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life:_Alyx',
#   'Metascore': '93',
#   'User Score': '9.2'},
#  {'Name': 'Aperture Desk Job',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Aperture_desk_job_logo.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Composer(s)': ['Mike Morasky'],
#   'Series': 'Portal',
#   'Engine': 'Source 2',
#   'Platform(s)': ['Windows', 'Linux'],
#   'Release': datetime.datetime(2022, 3, 1, 0, 0),
#   'Genre(s)': 'Action',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Aperture_Desk_Job',
#   'Metascore': 'N/A',
#   'User Score': '8.6'},
#  {'Name': "Garry's Mod",
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Garry%27s_Mod_logo.svg',
#   'Developer(s)': 'Facepunch Studios',
#   'Publisher(s)': 'Valve',
#   'Designer(s)': 'Garry Newman',
#   'Programmer(s)': 'Garry Newman',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows', 'Mac OS X', 'Linux'],
#   'Release': datetime.datetime(2006, 11, 29, 0, 0),
#   'Genre(s)': 'Sandbox',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Garry%27s_Mod',
#   'Metascore': 'N/A',
#   'User Score': '8.9'}]

# %%
# to be solved: https://en.wikipedia.org/wiki/Justice_League_Task_Force_(video_game) see developers
blizzard_games
# Out:
# [{'Name': 'RPM Racing',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:RPM_Racing_cover.jpg',
#   'Developer(s)': 'Silicon & Synapse',
#   'Publisher(s)': ['Interplay Productions', 'Victor Musical Industries'],
#   'Producer(s)': 'Michael Quarles',
#   'Programmer(s)': 'Allen Adham',
#   'Artist(s)': 'Rob Nesler',
#   'Composer(s)': 'George Alistair Sanger',
#   'Platform(s)': ['Super NES',
#    'Windows',
#    'Switch',
#    'PlayStation 4',
#    'Xbox One'],
#   'Release': datetime.datetime(1992, 3, 19, 0, 0),
#   'Genre(s)': 'Racing',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/RPM_Racing',
#   'Metascore': 'N/A',
#   'User Score': 'N/A'},
#  {'Name': 'The Lost Vikings',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:The_Lost_Vikings_SNES_cover.jpg',
#   'Developer(s)': 'Silicon & Synapse',
#   'Publisher(s)': ['Interplay Productions',
#    'T&E Soft',
#    'Blizzard Entertainment'],
#   'Designer(s)': 'Ron Millar',
#   'Composer(s)': 'Charles Deenen',
#   'Platform(s)': ['Super Nintendo',
#    'Genesis',
#    'Amiga',
#    'MS-DOS',
#    'Amiga CD32',
#    'Game Boy Advance',
#    'Windows',
#    'Switch',
#    'PlayStation 4',
#    'Xbox One'],
#   'Release': datetime.datetime(1993, 4, 29, 0, 0),
#   'Genre(s)': 'Puzzle-platform',
#   'Mode(s)': ['Single-player', 'cooperative'],
#   'Source': 'https://en.wikipedia.org/wiki/The_Lost_Vikings',
#   'Metascore': 'N/A',
#   'User Score': 'N/A'},
#  {'Name': "Rock n' Roll Racing",
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Rock_N%27_Roll_Racing_Cover.jpg',
#   'Developer(s)': ['Software Creations'],
#   'Publisher(s)': ['Interplay Productions', 'Namco', 'Blizzard Entertainment'],
#   'Designer(s)': 'Alan Pavlish',
#   'Programmer(s)': ['Bob Fitch', 'Patrick Wyatt', 'Ayman Adham'],
#   'Artist(s)': ['Samwise Didier', 'Ronald Millar Sr.', 'Joeyray Hall'],
#   'Composer(s)': 'Tim Follin and Geoff Follin',
#   'Platform(s)': ['Super NES',
#    'Mega Drive/Genesis',
#    'Game Boy Advance',
#    'Microsoft Windows',
#    'Xbox One',
#    'PlayStation 4',
#    'Nintendo Switch'],
#   'Release': datetime.datetime(1993, 6, 4, 0, 0),
#   'Genre(s)': 'Racing',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Rock_n%27_Roll_Racing',
#   'Metascore': 'N/A',
#   'User Score': 'N/A'},
#  {'Name': 'The Death and Return of Superman',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:The_Death_and_Return_of_Superman.png',
#   'Developer(s)': ['Blizzard Entertainment', 'Sunsoft'],
#   'Publisher(s)': 'Sunsoft',
#   'Designer(s)': 'Dan MacArthur',
#   'Programmer(s)': ['James Edward Anhalt III', 'Allen Adham', 'Bob Fitch'],
#   'Artist(s)': ['Samwise Didier',
#    'David Berggren',
#    'Roman Kenney',
#    'Joeyray Hall',
#    'Stuart Rose',
#    'Ronald Millar Sr.'],
#   'Composer(s)': ['Michael Morhaime', 'Glenn Stafford'],
#   'Platform(s)': ['Super NES', 'Sega Genesis'],
#   'Release': None,
#   'Genre(s)': "Beat 'em up",
#   'Mode(s)': 'Single player',
#   'Source': 'https://en.wikipedia.org/wiki/The_Death_and_Return_of_Superman',
#   'Metascore': 'N/A',
#   'User Score': 'N/A'},
#  {'Name': 'Blackthorne',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:BlackthorneSNES.jpg',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Interplay Productions',
#   'Producer(s)': ['Ronald Millar Sr.', 'Matthew Findley'],
#   'Designer(s)': 'Ronald Millar Sr.',
#   'Programmer(s)': ['Frank Pearce Jr.', 'Patrick Wyatt'],
#   'Artist(s)': ['Roman Kenney',
#    'Stuart Rose',
#    'Jason Magness',
#    'Ronald Millar Sr.',
#    'Samwise Didier'],
#   'Writer(s)': ['Micky Neilson', 'Ronald Millar Sr.', 'Frank Pearce Jr.'],
#   'Composer(s)': 'Glenn Stafford',
#   'Platform(s)': ['SNES',
#    'MS-DOS',
#    'Sega 32X',
#    'Classic Mac OS',
#    'Game Boy Advance',
#    'Microsoft Windows',
#    'Xbox One',
#    'PlayStation 4',
#    'Nintendo Switch'],
#   'Release': datetime.datetime(2021, 2, 20, 0, 0),
#   'Genre(s)': 'Platform',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Blackthorne',
#   'Metascore': 'N/A',
#   'User Score': 'N/A'},
#  {'Name': 'Warcraft: Orcs & Humans',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Warcraft_-_Orcs_%26_Humans_Coverart.png',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': ['EU:Interplay Productions'],
#   'Director(s)': 'Patrick Wyatt',
#   'Producer(s)': ['Bill Roper', 'Patrick Wyatt'],
#   'Programmer(s)': ['Bob Fitch',
#    'Jesse McReynolds',
#    'Michael Morhaime',
#    'Patrick Wyatt'],
#   'Composer(s)': 'Gregory Alper',
#   'Series': 'Warcraft',
#   'Platform(s)': ['MS-DOS', 'Classic Mac OS'],
#   'Release': datetime.datetime(1994, 11, 15, 0, 0),
#   'Genre(s)': 'Real-time strategy',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Warcraft:_Orcs_%26_Humans',
#   'Metascore': 'N/A',
#   'User Score': 'N/A'},
#  {'Name': 'Justice League Task Force',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Justice_League_Task_Force_game_cover.jpg',
#   'Developer(s)': ['Sunsoft',
#    'Super NES',
#    'Blizzard Entertainment',
#    'Mega Drive/Genesis',
#    'Condor, Inc.'],
#   'Publisher(s)': 'Acclaim Entertainment',
#   'Composer(s)': ['Matt Uelmen', 'Glenn Stafford'],
#   'Platform(s)': ['Genesis', 'Super NES'],
#   'Release': datetime.datetime(1995, 9, 1, 0, 0),
#   'Genre(s)': 'Fighting',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Justice_League_Task_Force_(video_game)',
#   'Metascore': 'N/A',
#   'User Score': 'N/A'},
#  {'Name': 'Warcraft II: Tides of Darkness',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Warcraft-2-Tides-Of-Darkness-Pc.jpg',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Davidson & Associates',
#   'Producer(s)': ['Sam Didier', 'Michael Morhaime', 'Patrick Wyatt'],
#   'Designer(s)': 'Ron Millar',
#   'Programmer(s)': ['Bob Fitch', 'Jesse McReynolds', 'Michael Morhaime'],
#   'Writer(s)': 'Chris Metzen',
#   'Composer(s)': 'Glenn Stafford',
#   'Series': 'Warcraft',
#   'Platform(s)': ['MS-DOS',
#    'Classic Mac OS',
#    'Saturn',
#    'PlayStation',
#    'Microsoft Windows'],
#   'Release': datetime.datetime(1995, 12, 9, 0, 0),
#   'Genre(s)': 'Real-time strategy',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Warcraft_II:_Tides_of_Darkness',
#   'Metascore': 'N/A',
#   'User Score': '9.0'},
#  {'Name': 'Diablo',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Diablo_Coverart.png',
#   'Developer(s)': 'Blizzard North',
#   'Publisher(s)': ['Blizzard Entertainment,Davidson & Associates'],
#   'Producer(s)': 'Bill Roper',
#   'Designer(s)': ['David Brevik',
#    'Erich Schaefer',
#    'Max Schaefer',
#    'Eric Sexton',
#    'Kenneth Williams'],
#   'Programmer(s)': 'David Brevik',
#   'Artist(s)': 'Michio Okamura',
#   'Writer(s)': ['Chris Metzen', 'Bill Roper', 'Eric Sexton', 'Erich Schaefer'],
#   'Composer(s)': 'Matt Uelmen',
#   'Series': 'Diablo',
#   'Platform(s)': ['Microsoft Windows', 'PlayStation', 'Mac OS'],
#   'Release': datetime.datetime(1997, 1, 3, 0, 0),
#   'Genre(s)': 'Action role-playing',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Diablo_(video_game)',
#   'Metascore': '94',
#   'User Score': '8.6'},
#  {'Name': 'Lost Vikings 2',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Lost_Vikings_2_Boxshot.jpg',
#   'Developer(s)': ['Blizzard Entertainment', 'Beam Software'],
#   'Publisher(s)': 'Interplay Productions',
#   'Producer(s)': 'Feargus Urquhart',
#   'Designer(s)': 'Ron Millar',
#   'Programmer(s)': 'James Phinney',
#   'Artist(s)': 'Samwise Didier',
#   'Composer(s)': 'Glenn Stafford',
#   'Platform(s)': ['Super NES',
#    'MS-DOS',
#    'Windows',
#    'Saturn',
#    'PlayStation',
#    'Switch',
#    'PlayStation 4',
#    'Xbox One'],
#   'Release': datetime.datetime(1997, 2, 27, 0, 0),
#   'Genre(s)': 'Puzzle-platform',
#   'Mode(s)': ['Single-player', '2 player cooperative'],
#   'Source': 'https://en.wikipedia.org/wiki/The_Lost_Vikings_2',
#   'Metascore': 'N/A',
#   'User Score': 'N/A'},
#  {'Name': 'StarCraft',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:StarCraft_box_art.jpg',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Designer(s)': ['Chris Metzen', 'James Phinney'],
#   'Composer(s)': ['Derek Duke',
#    'Jason Hayes',
#    'Glenn Stafford',
#    'Tracy W. Bush'],
#   'Series': 'StarCraft',
#   'Platform(s)': ['Microsoft Windows', 'Classic Mac OS', 'Nintendo 64'],
#   'Release': datetime.datetime(1998, 3, 31, 0, 0),
#   'Genre(s)': 'Real-time strategy',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/StarCraft_(video_game)',
#   'Metascore': '88',
#   'User Score': '9.1'},
#  {'Name': 'Diablo II',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Diablo_II_Coverart.png',
#   'Developer(s)': 'Blizzard North',
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Director(s)': ['David Brevik', 'Erich Schaefer', 'Max Schaefer'],
#   'Producer(s)': ['Mark Kern', 'Kenneth Williams'],
#   'Designer(s)': ['David Brevik', 'Erich Schaefer', 'Max Schaefer'],
#   'Programmer(s)': 'Rick Seis',
#   'Artist(s)': 'Phil Shenk',
#   'Writer(s)': ['Kurt Beaver',
#    'Stieg Hedlund',
#    'Matthew Householder',
#    'Phil Shenk',
#    'Robert Vieira'],
#   'Composer(s)': 'Matt Uelmen',
#   'Series': 'Diablo',
#   'Platform(s)': ['Microsoft Windows', 'Classic Mac OS', 'macOS'],
#   'Release': datetime.datetime(2000, 6, 29, 0, 0),
#   'Genre(s)': ['Action role-playing', 'hack and slash'],
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Diablo_II',
#   'Metascore': '88',
#   'User Score': '8.7'},
#  {'Name': 'Warcraft III: Reign of Chaos',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:WarcraftIII.jpg',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Director(s)': 'Frank Pearce Jr.',
#   'Producer(s)': 'Chris Sigaty',
#   'Designer(s)': 'Rob Pardo',
#   'Writer(s)': 'Chris Metzen',
#   'Composer(s)': ['Tracy W. Bush', 'Derek Duke', 'Glenn Stafford'],
#   'Series': 'Warcraft',
#   'Platform(s)': ['Microsoft Windows', 'Classic Mac OS', 'Mac OS X'],
#   'Release': datetime.datetime(2002, 7, 3, 0, 0),
#   'Genre(s)': 'Real-time strategy',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Warcraft_III:_Reign_of_Chaos',
#   'Metascore': '92',
#   'User Score': '9.2'},
#  {'Name': 'World of Warcraft',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:World_of_Warcraft.png',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Designer(s)': ['Rob Pardo', 'Jeff Kaplan', 'Tom Chilton'],
#   'Composer(s)': 'Jason Hayes',
#   'Series': 'Warcraft',
#   'Platform(s)': ['Microsoft Windows', 'macOS'],
#   'Release': datetime.datetime(2004, 11, 23, 0, 0),
#   'Genre(s)': 'Massively multiplayer online role-playing',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/World_of_Warcraft',
#   'Metascore': '93',
#   'User Score': '7.4'},
#  {'Name': 'StarCraft II: Wings of Liberty',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:StarCraft_II_-_Box_Art.jpg',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Producer(s)': 'Chris Sigaty',
#   'Designer(s)': 'Dustin Browder',
#   'Programmer(s)': ['Carl Chimes', 'Bob Fitch'],
#   'Artist(s)': 'Samwise Didier',
#   'Writer(s)': ['Chris Metzen', 'Andrew Chambers', 'Brian Kindregan'],
#   'Composer(s)': ['Derek Duke',
#    'Glenn Stafford',
#    'Russell Brower',
#    'Neal Acree'],
#   'Series': 'StarCraft',
#   'Platform(s)': ['Microsoft Windows', 'macOS'],
#   'Release': datetime.datetime(2010, 7, 27, 0, 0),
#   'Genre(s)': 'Real-time strategy',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/StarCraft_II:_Wings_of_Liberty',
#   'Metascore': '93',
#   'User Score': '8.3'},
#  {'Name': 'Diablo III',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Diablo_III_cover.png',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Director(s)': 'Jay Wilson',
#   'Producer(s)': 'Alex Mayberry',
#   'Designer(s)': ['Kevin Martens', 'David M. Adams'],
#   'Programmer(s)': 'Jason Regier',
#   'Artist(s)': 'Christian Lichtner',
#   'Writer(s)': 'Chris Metzen',
#   'Composer(s)': 'Russell Brower',
#   'Series': 'Diablo',
#   'Platform(s)': ['Microsoft Windows',
#    'OS X',
#    'PlayStation 3',
#    'Xbox 360',
#    'PlayStation 4',
#    'Xbox One',
#    'Nintendo Switch'],
#   'Release': datetime.datetime(2012, 5, 15, 0, 0),
#   'Genre(s)': ['Action role-playing', 'hack and slash'],
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Diablo_III',
#   'Metascore': '88',
#   'User Score': '4.1'},
#  {'Name': 'Hearthstone: Heroes of Warcraft',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Hearthstone_2016_logo.png',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Director(s)': ['Ben Brode', 'Jason Chayes', 'Eric Dodds'],
#   'Designer(s)': ['Derek Sakamoto', 'Mike Donais'],
#   'Composer(s)': 'Peter McConnell',
#   'Series': 'Warcraft',
#   'Engine': 'Unity',
#   'Platform(s)': ['Microsoft Windows', 'macOS', 'iOS', 'Android'],
#   'Release': datetime.datetime(2014, 3, 11, 0, 0),
#   'Genre(s)': 'Digital collectible card game',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Hearthstone',
#   'Metascore': '88',
#   'User Score': '5.7'},
#  {'Name': 'Heroes of the Storm',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Heroes_of_the_Storm_BlizzHeroes_2017_logo.png',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Director(s)': ['Dustin Browder', 'Alan Dabiri'],
#   'Producer(s)': 'Kaéo Milker',
#   'Composer(s)': ['Glenn Stafford', 'Jason Hayes'],
#   'Platform(s)': ['Microsoft Windows', 'macOS'],
#   'Release': datetime.datetime(2015, 6, 2, 0, 0),
#   'Genre(s)': 'MOBA',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Heroes_of_the_Storm',
#   'Metascore': '86',
#   'User Score': '6.3'},
#  {'Name': 'Overwatch',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Overwatch_cover_art.jpg',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Director(s)': ['Jeff Kaplan', 'Chris Metzen', 'Aaron Keller'],
#   'Designer(s)': ['Jeremy Craig', 'Michael Elliott', 'Scott Mercer'],
#   'Programmer(s)': ['Mike Elliott', 'John LeFleur'],
#   'Artist(s)': ['William Petras', 'Arnold Tsang'],
#   'Writer(s)': ['Michael Chu', 'Alyssa Wong'],
#   'Composer(s)': 'Derek Duke',
#   'Platform(s)': ['Microsoft Windows',
#    'PlayStation 4',
#    'Xbox One',
#    'Nintendo Switch'],
#   'Release': datetime.datetime(2016, 5, 24, 0, 0),
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Overwatch',
#   'Metascore': '91',
#   'User Score': '6.4'},
#  {'Name': 'Diablo Immortal',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Diablo_Immortal_App_Logo.png',
#   'Developer(s)': ['Blizzard Entertainment', 'NetEase'],
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Director(s)': 'Wyatt Cheng',
#   'Series': 'Diablo',
#   'Platform(s)': ['Android', 'iOS', 'Windows'],
#   'Release': datetime.datetime(2022, 6, 2, 0, 0),
#   'Genre(s)': ['Action role-playing', 'Massively multiplayer online'],
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Diablo_Immortal',
#   'Metascore': 'N/A',
#   'User Score': 'N/A'}]

# %%
blizzard_games[10]
# Out:
# {'Name': 'StarCraft',
#  'Image_link': 'https://en.wikipedia.org/wiki/File:StarCraft_box_art.jpg',
#  'Developer(s)': 'Blizzard Entertainment',
#  'Publisher(s)': 'Blizzard Entertainment',
#  'Designer(s)': ['Chris Metzen', 'James Phinney'],
#  'Composer(s)': ['Derek Duke',
#   'Jason Hayes',
#   'Glenn Stafford',
#   'Tracy W. Bush'],
#  'Series': 'StarCraft',
#  'Platform(s)': ['Microsoft Windows', 'Classic Mac OS', 'Nintendo 64'],
#  'Release': datetime.datetime(1998, 3, 31, 0, 0),
#  'Genre(s)': 'Real-time strategy',
#  'Mode(s)': ['Single-player', 'multiplayer'],
#  'Source': 'https://en.wikipedia.org/wiki/StarCraft_(video_game)',
#  'Metascore': '88',
#  'User Score': '9.1'}

# %%
import json

def save_json(filename, data):
    with open(filename, 'w') as f:
        json.dump(data, f)
        
def load_json(filename):
    with open(filename, 'r') as f:
        return json.load(f)

# %%
import pickle

def save_pickle(filename, data):
    with open(filename, 'wb') as f:
        pickle.dump(data, f)

def load_pickle(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# %%
#save_pickle('valve_cleaned_pickle.pickle', valve_games)
#save_pickle('blizzard_cleaned_pickle.pickle', blizzard_games)

# %%
valve_games = load_pickle('valve_cleaned_pickle.pickle')
blizzard_games = load_pickle('blizzard_cleaned_pickle.pickle')

# %%
# To fix: make sure all str get converted to datetime objects
    # Nones get removed (?)
blizzard_games
# Out:
# [{'Name': 'RPM Racing',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:RPM_Racing_cover.jpg',
#   'Developer(s)': 'Silicon & Synapse',
#   'Publisher(s)': ['Interplay Productions', 'Victor Musical Industries'],
#   'Producer(s)': 'Michael Quarles',
#   'Programmer(s)': 'Allen Adham',
#   'Artist(s)': 'Rob Nesler',
#   'Composer(s)': 'George Alistair Sanger',
#   'Platform(s)': ['Super NES',
#    'Windows',
#    'Switch',
#    'PlayStation 4',
#    'Xbox One'],
#   'Release': datetime.datetime(1992, 3, 19, 0, 0),
#   'Genre(s)': 'Racing',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/RPM_Racing',
#   'Metascore': 'N/A',
#   'User Score': 'N/A'},
#  {'Name': 'The Lost Vikings',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:The_Lost_Vikings_SNES_cover.jpg',
#   'Developer(s)': 'Silicon & Synapse',
#   'Publisher(s)': ['Interplay Productions',
#    'T&E Soft',
#    'Blizzard Entertainment'],
#   'Designer(s)': 'Ron Millar',
#   'Composer(s)': 'Charles Deenen',
#   'Platform(s)': ['Super Nintendo',
#    'Genesis',
#    'Amiga',
#    'MS-DOS',
#    'Amiga CD32',
#    'Game Boy Advance',
#    'Windows',
#    'Switch',
#    'PlayStation 4',
#    'Xbox One'],
#   'Release': datetime.datetime(1993, 4, 29, 0, 0),
#   'Genre(s)': 'Puzzle-platform',
#   'Mode(s)': ['Single-player', 'cooperative'],
#   'Source': 'https://en.wikipedia.org/wiki/The_Lost_Vikings',
#   'Metascore': 'N/A',
#   'User Score': 'N/A'},
#  {'Name': "Rock n' Roll Racing",
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Rock_N%27_Roll_Racing_Cover.jpg',
#   'Developer(s)': ['Software Creations'],
#   'Publisher(s)': ['Interplay Productions', 'Namco', 'Blizzard Entertainment'],
#   'Designer(s)': 'Alan Pavlish',
#   'Programmer(s)': ['Bob Fitch', 'Patrick Wyatt', 'Ayman Adham'],
#   'Artist(s)': ['Samwise Didier', 'Ronald Millar Sr.', 'Joeyray Hall'],
#   'Composer(s)': 'Tim Follin and Geoff Follin',
#   'Platform(s)': ['Super NES',
#    'Mega Drive/Genesis',
#    'Game Boy Advance',
#    'Microsoft Windows',
#    'Xbox One',
#    'PlayStation 4',
#    'Nintendo Switch'],
#   'Release': datetime.datetime(1993, 6, 4, 0, 0),
#   'Genre(s)': 'Racing',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Rock_n%27_Roll_Racing',
#   'Metascore': 'N/A',
#   'User Score': 'N/A'},
#  {'Name': 'The Death and Return of Superman',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:The_Death_and_Return_of_Superman.png',
#   'Developer(s)': ['Blizzard Entertainment', 'Sunsoft'],
#   'Publisher(s)': 'Sunsoft',
#   'Designer(s)': 'Dan MacArthur',
#   'Programmer(s)': ['James Edward Anhalt III', 'Allen Adham', 'Bob Fitch'],
#   'Artist(s)': ['Samwise Didier',
#    'David Berggren',
#    'Roman Kenney',
#    'Joeyray Hall',
#    'Stuart Rose',
#    'Ronald Millar Sr.'],
#   'Composer(s)': ['Michael Morhaime', 'Glenn Stafford'],
#   'Platform(s)': ['Super NES', 'Sega Genesis'],
#   'Release': None,
#   'Genre(s)': "Beat 'em up",
#   'Mode(s)': 'Single player',
#   'Source': 'https://en.wikipedia.org/wiki/The_Death_and_Return_of_Superman',
#   'Metascore': 'N/A',
#   'User Score': 'N/A'},
#  {'Name': 'Blackthorne',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:BlackthorneSNES.jpg',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Interplay Productions',
#   'Producer(s)': ['Ronald Millar Sr.', 'Matthew Findley'],
#   'Designer(s)': 'Ronald Millar Sr.',
#   'Programmer(s)': ['Frank Pearce Jr.', 'Patrick Wyatt'],
#   'Artist(s)': ['Roman Kenney',
#    'Stuart Rose',
#    'Jason Magness',
#    'Ronald Millar Sr.',
#    'Samwise Didier'],
#   'Writer(s)': ['Micky Neilson', 'Ronald Millar Sr.', 'Frank Pearce Jr.'],
#   'Composer(s)': 'Glenn Stafford',
#   'Platform(s)': ['SNES',
#    'MS-DOS',
#    'Sega 32X',
#    'Classic Mac OS',
#    'Game Boy Advance',
#    'Microsoft Windows',
#    'Xbox One',
#    'PlayStation 4',
#    'Nintendo Switch'],
#   'Release': datetime.datetime(2021, 2, 20, 0, 0),
#   'Genre(s)': 'Platform',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Blackthorne',
#   'Metascore': 'N/A',
#   'User Score': 'N/A'},
#  {'Name': 'Warcraft: Orcs & Humans',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Warcraft_-_Orcs_%26_Humans_Coverart.png',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': ['EU:Interplay Productions'],
#   'Director(s)': 'Patrick Wyatt',
#   'Producer(s)': ['Bill Roper', 'Patrick Wyatt'],
#   'Programmer(s)': ['Bob Fitch',
#    'Jesse McReynolds',
#    'Michael Morhaime',
#    'Patrick Wyatt'],
#   'Composer(s)': 'Gregory Alper',
#   'Series': 'Warcraft',
#   'Platform(s)': ['MS-DOS', 'Classic Mac OS'],
#   'Release': datetime.datetime(1994, 11, 15, 0, 0),
#   'Genre(s)': 'Real-time strategy',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Warcraft:_Orcs_%26_Humans',
#   'Metascore': 'N/A',
#   'User Score': 'N/A'},
#  {'Name': 'Justice League Task Force',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Justice_League_Task_Force_game_cover.jpg',
#   'Developer(s)': ['Sunsoft',
#    'Super NES',
#    'Blizzard Entertainment',
#    'Mega Drive/Genesis',
#    'Condor, Inc.'],
#   'Publisher(s)': 'Acclaim Entertainment',
#   'Composer(s)': ['Matt Uelmen', 'Glenn Stafford'],
#   'Platform(s)': ['Genesis', 'Super NES'],
#   'Release': datetime.datetime(1995, 9, 1, 0, 0),
#   'Genre(s)': 'Fighting',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Justice_League_Task_Force_(video_game)',
#   'Metascore': 'N/A',
#   'User Score': 'N/A'},
#  {'Name': 'Warcraft II: Tides of Darkness',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Warcraft-2-Tides-Of-Darkness-Pc.jpg',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Davidson & Associates',
#   'Producer(s)': ['Sam Didier', 'Michael Morhaime', 'Patrick Wyatt'],
#   'Designer(s)': 'Ron Millar',
#   'Programmer(s)': ['Bob Fitch', 'Jesse McReynolds', 'Michael Morhaime'],
#   'Writer(s)': 'Chris Metzen',
#   'Composer(s)': 'Glenn Stafford',
#   'Series': 'Warcraft',
#   'Platform(s)': ['MS-DOS',
#    'Classic Mac OS',
#    'Saturn',
#    'PlayStation',
#    'Microsoft Windows'],
#   'Release': datetime.datetime(1995, 12, 9, 0, 0),
#   'Genre(s)': 'Real-time strategy',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Warcraft_II:_Tides_of_Darkness',
#   'Metascore': 'N/A',
#   'User Score': '9.0'},
#  {'Name': 'Diablo',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Diablo_Coverart.png',
#   'Developer(s)': 'Blizzard North',
#   'Publisher(s)': ['Blizzard Entertainment,Davidson & Associates'],
#   'Producer(s)': 'Bill Roper',
#   'Designer(s)': ['David Brevik',
#    'Erich Schaefer',
#    'Max Schaefer',
#    'Eric Sexton',
#    'Kenneth Williams'],
#   'Programmer(s)': 'David Brevik',
#   'Artist(s)': 'Michio Okamura',
#   'Writer(s)': ['Chris Metzen', 'Bill Roper', 'Eric Sexton', 'Erich Schaefer'],
#   'Composer(s)': 'Matt Uelmen',
#   'Series': 'Diablo',
#   'Platform(s)': ['Microsoft Windows', 'PlayStation', 'Mac OS'],
#   'Release': datetime.datetime(1997, 1, 3, 0, 0),
#   'Genre(s)': 'Action role-playing',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Diablo_(video_game)',
#   'Metascore': '94',
#   'User Score': '8.6'},
#  {'Name': 'Lost Vikings 2',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Lost_Vikings_2_Boxshot.jpg',
#   'Developer(s)': ['Blizzard Entertainment', 'Beam Software'],
#   'Publisher(s)': 'Interplay Productions',
#   'Producer(s)': 'Feargus Urquhart',
#   'Designer(s)': 'Ron Millar',
#   'Programmer(s)': 'James Phinney',
#   'Artist(s)': 'Samwise Didier',
#   'Composer(s)': 'Glenn Stafford',
#   'Platform(s)': ['Super NES',
#    'MS-DOS',
#    'Windows',
#    'Saturn',
#    'PlayStation',
#    'Switch',
#    'PlayStation 4',
#    'Xbox One'],
#   'Release': datetime.datetime(1997, 2, 27, 0, 0),
#   'Genre(s)': 'Puzzle-platform',
#   'Mode(s)': ['Single-player', '2 player cooperative'],
#   'Source': 'https://en.wikipedia.org/wiki/The_Lost_Vikings_2',
#   'Metascore': 'N/A',
#   'User Score': 'N/A'},
#  {'Name': 'StarCraft',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:StarCraft_box_art.jpg',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Designer(s)': ['Chris Metzen', 'James Phinney'],
#   'Composer(s)': ['Derek Duke',
#    'Jason Hayes',
#    'Glenn Stafford',
#    'Tracy W. Bush'],
#   'Series': 'StarCraft',
#   'Platform(s)': ['Microsoft Windows', 'Classic Mac OS', 'Nintendo 64'],
#   'Release': datetime.datetime(1998, 3, 31, 0, 0),
#   'Genre(s)': 'Real-time strategy',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/StarCraft_(video_game)',
#   'Metascore': '88',
#   'User Score': '9.1'},
#  {'Name': 'Diablo II',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Diablo_II_Coverart.png',
#   'Developer(s)': 'Blizzard North',
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Director(s)': ['David Brevik', 'Erich Schaefer', 'Max Schaefer'],
#   'Producer(s)': ['Mark Kern', 'Kenneth Williams'],
#   'Designer(s)': ['David Brevik', 'Erich Schaefer', 'Max Schaefer'],
#   'Programmer(s)': 'Rick Seis',
#   'Artist(s)': 'Phil Shenk',
#   'Writer(s)': ['Kurt Beaver',
#    'Stieg Hedlund',
#    'Matthew Householder',
#    'Phil Shenk',
#    'Robert Vieira'],
#   'Composer(s)': 'Matt Uelmen',
#   'Series': 'Diablo',
#   'Platform(s)': ['Microsoft Windows', 'Classic Mac OS', 'macOS'],
#   'Release': datetime.datetime(2000, 6, 29, 0, 0),
#   'Genre(s)': ['Action role-playing', 'hack and slash'],
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Diablo_II',
#   'Metascore': '88',
#   'User Score': '8.7'},
#  {'Name': 'Warcraft III: Reign of Chaos',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:WarcraftIII.jpg',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Director(s)': 'Frank Pearce Jr.',
#   'Producer(s)': 'Chris Sigaty',
#   'Designer(s)': 'Rob Pardo',
#   'Writer(s)': 'Chris Metzen',
#   'Composer(s)': ['Tracy W. Bush', 'Derek Duke', 'Glenn Stafford'],
#   'Series': 'Warcraft',
#   'Platform(s)': ['Microsoft Windows', 'Classic Mac OS', 'Mac OS X'],
#   'Release': datetime.datetime(2002, 7, 3, 0, 0),
#   'Genre(s)': 'Real-time strategy',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Warcraft_III:_Reign_of_Chaos',
#   'Metascore': '92',
#   'User Score': '9.2'},
#  {'Name': 'World of Warcraft',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:World_of_Warcraft.png',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Designer(s)': ['Rob Pardo', 'Jeff Kaplan', 'Tom Chilton'],
#   'Composer(s)': 'Jason Hayes',
#   'Series': 'Warcraft',
#   'Platform(s)': ['Microsoft Windows', 'macOS'],
#   'Release': datetime.datetime(2004, 11, 23, 0, 0),
#   'Genre(s)': 'Massively multiplayer online role-playing',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/World_of_Warcraft',
#   'Metascore': '93',
#   'User Score': '7.4'},
#  {'Name': 'StarCraft II: Wings of Liberty',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:StarCraft_II_-_Box_Art.jpg',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Producer(s)': 'Chris Sigaty',
#   'Designer(s)': 'Dustin Browder',
#   'Programmer(s)': ['Carl Chimes', 'Bob Fitch'],
#   'Artist(s)': 'Samwise Didier',
#   'Writer(s)': ['Chris Metzen', 'Andrew Chambers', 'Brian Kindregan'],
#   'Composer(s)': ['Derek Duke',
#    'Glenn Stafford',
#    'Russell Brower',
#    'Neal Acree'],
#   'Series': 'StarCraft',
#   'Platform(s)': ['Microsoft Windows', 'macOS'],
#   'Release': datetime.datetime(2010, 7, 27, 0, 0),
#   'Genre(s)': 'Real-time strategy',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/StarCraft_II:_Wings_of_Liberty',
#   'Metascore': '93',
#   'User Score': '8.3'},
#  {'Name': 'Diablo III',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Diablo_III_cover.png',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Director(s)': 'Jay Wilson',
#   'Producer(s)': 'Alex Mayberry',
#   'Designer(s)': ['Kevin Martens', 'David M. Adams'],
#   'Programmer(s)': 'Jason Regier',
#   'Artist(s)': 'Christian Lichtner',
#   'Writer(s)': 'Chris Metzen',
#   'Composer(s)': 'Russell Brower',
#   'Series': 'Diablo',
#   'Platform(s)': ['Microsoft Windows',
#    'OS X',
#    'PlayStation 3',
#    'Xbox 360',
#    'PlayStation 4',
#    'Xbox One',
#    'Nintendo Switch'],
#   'Release': datetime.datetime(2012, 5, 15, 0, 0),
#   'Genre(s)': ['Action role-playing', 'hack and slash'],
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Diablo_III',
#   'Metascore': '88',
#   'User Score': '4.1'},
#  {'Name': 'Hearthstone: Heroes of Warcraft',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Hearthstone_2016_logo.png',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Director(s)': ['Ben Brode', 'Jason Chayes', 'Eric Dodds'],
#   'Designer(s)': ['Derek Sakamoto', 'Mike Donais'],
#   'Composer(s)': 'Peter McConnell',
#   'Series': 'Warcraft',
#   'Engine': 'Unity',
#   'Platform(s)': ['Microsoft Windows', 'macOS', 'iOS', 'Android'],
#   'Release': datetime.datetime(2014, 3, 11, 0, 0),
#   'Genre(s)': 'Digital collectible card game',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Hearthstone',
#   'Metascore': '88',
#   'User Score': '5.7'},
#  {'Name': 'Heroes of the Storm',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Heroes_of_the_Storm_BlizzHeroes_2017_logo.png',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Director(s)': ['Dustin Browder', 'Alan Dabiri'],
#   'Producer(s)': 'Kaéo Milker',
#   'Composer(s)': ['Glenn Stafford', 'Jason Hayes'],
#   'Platform(s)': ['Microsoft Windows', 'macOS'],
#   'Release': datetime.datetime(2015, 6, 2, 0, 0),
#   'Genre(s)': 'MOBA',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Heroes_of_the_Storm',
#   'Metascore': '86',
#   'User Score': '6.3'},
#  {'Name': 'Overwatch',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Overwatch_cover_art.jpg',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Director(s)': ['Jeff Kaplan', 'Chris Metzen', 'Aaron Keller'],
#   'Designer(s)': ['Jeremy Craig', 'Michael Elliott', 'Scott Mercer'],
#   'Programmer(s)': ['Mike Elliott', 'John LeFleur'],
#   'Artist(s)': ['William Petras', 'Arnold Tsang'],
#   'Writer(s)': ['Michael Chu', 'Alyssa Wong'],
#   'Composer(s)': 'Derek Duke',
#   'Platform(s)': ['Microsoft Windows',
#    'PlayStation 4',
#    'Xbox One',
#    'Nintendo Switch'],
#   'Release': datetime.datetime(2016, 5, 24, 0, 0),
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Overwatch',
#   'Metascore': '91',
#   'User Score': '6.4'},
#  {'Name': 'Diablo Immortal',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Diablo_Immortal_App_Logo.png',
#   'Developer(s)': ['Blizzard Entertainment', 'NetEase'],
#   'Publisher(s)': 'Blizzard Entertainment',
#   'Director(s)': 'Wyatt Cheng',
#   'Series': 'Diablo',
#   'Platform(s)': ['Android', 'iOS', 'Windows'],
#   'Release': datetime.datetime(2022, 6, 2, 0, 0),
#   'Genre(s)': ['Action role-playing', 'Massively multiplayer online'],
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Diablo_Immortal',
#   'Metascore': 'N/A',
#   'User Score': 'N/A'}]

# %%
from datetime import datetime

# converts datetime objects in game dictionaries to strings
def json_friendly(game_dict):
    for i, game in enumerate(game_dict):
        #print(f'Game number {i}')
        datetime_obj = game['Release']
        if datetime_obj == None:
            continue
        date_str = datetime_obj.strftime('%B %d, %Y')
        game['Release'] = date_str
        #print(game['Release'])
    return game_dict
    
#a = json_friendly(blizzard_games)

# %%
valve_json = json_friendly(valve_games)
blizzard_json = json_friendly(blizzard_games)

# %%
save_json('valve_cleaned_json.json', valve_json)
save_json('blizzard_cleaned_json.json', blizzard_json)

# %%
#load_json('valve_cleaned_json.json')

# %%
valve_games
# Out:
# [{'Name': 'Half-Life',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_Cover_Art.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Sierra Studios',
#   'Writer(s)': 'Marc Laidlaw',
#   'Composer(s)': 'Kelly Bailey',
#   'Series': 'Half-Life',
#   'Engine': 'GoldSrc',
#   'Platform(s)': ['Windows', 'PlayStation 2', 'OS X', 'Linux'],
#   'Release': 'November 19, 1998',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life_(video_game)',
#   'Metascore': '96',
#   'User Score': '9.1'},
#  {'Name': 'Team Fortress Classic',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Team_Fortress_Classic_box.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': ['Sierra Studios'],
#   'Designer(s)': ['John Cook', 'Robin Walker'],
#   'Engine': 'GoldSrc',
#   'Platform(s)': ['Microsoft Windows', 'OS X', 'Linux'],
#   'Release': 'April 07, 1999',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Team_Fortress_Classic',
#   'Metascore': 'N/A',
#   'User Score': '7.2'},
#  {'Name': 'Counter-Strike',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Counter-Strike_Box.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': ['Sierra Studios'],
#   'Designer(s)': ['Minh Le', 'Jess Cliffe'],
#   'Series': 'Counter-Strike',
#   'Engine': 'GoldSrc',
#   'Platform(s)': ['Windows', 'Xbox', 'OS X', 'Linux'],
#   'Release': 'November 09, 2000',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Counter-Strike_(video_game)',
#   'Metascore': '88',
#   'User Score': '9.2'},
#  {'Name': 'Day of Defeat',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Day_of_Defeat_cover_art.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': ['Activision'],
#   'Composer(s)': 'Michael Gordon Shapiro',
#   'Engine': 'GoldSrc',
#   'Platform(s)': ['Microsoft Windows', 'OS X', 'Linux'],
#   'Release': 'May 06, 2003',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Day_of_Defeat',
#   'Metascore': '79',
#   'User Score': '9.0'},
#  {'Name': 'Counter-Strike: Condition Zero',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:CZbox.jpg',
#   'Developer(s)': ['Ritual Entertainment', 'Turtle Rock Studios', 'Valve'],
#   'Publisher(s)': ['Sierra Entertainment'],
#   'Series': 'Counter-Strike',
#   'Engine': 'GoldSrc',
#   'Platform(s)': ['Windows', 'OS X', 'Linux'],
#   'Release': 'March 23, 2004',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Counter-Strike:_Condition_Zero',
#   'Metascore': '65',
#   'User Score': '8.7'},
#  {'Name': 'Counter-Strike: Source',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Counter-Strike_Source_(box_art).jpg',
#   'Developer(s)': ['Valve', 'Turtle Rock Studios'],
#   'Publisher(s)': 'Valve',
#   'Series': 'Counter-Strike',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows', 'Mac OS X', 'Linux'],
#   'Release': 'October 07, 2004',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Counter-Strike:_Source',
#   'Metascore': '88',
#   'User Score': '8.9'},
#  {'Name': 'Half-Life 2',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_2_cover.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': ['Valve'],
#   'Artist(s)': 'Viktor Antonov',
#   'Writer(s)': 'Marc Laidlaw',
#   'Composer(s)': 'Kelly Bailey',
#   'Series': 'Half-Life',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows',
#    'Xbox',
#    'Xbox 360',
#    'PlayStation 3',
#    'Mac OS X',
#    'Linux',
#    'Android'],
#   'Release': 'November 16, 2004',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life_2',
#   'Metascore': '96',
#   'User Score': '9.2'},
#  {'Name': 'Half-Life 2: Deathmatch',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_2_Deathmatch_cover.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Series': 'Half-Life',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows', 'Mac OS X', 'Linux'],
#   'Release': 'November 30, 2004',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life_2:_Deathmatch',
#   'Metascore': 'N/A',
#   'User Score': '7.3'},
#  {'Name': 'Day of Defeat: Source',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:DODSourceCover.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Composer(s)': 'Dan Haigh',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows', 'Mac OS X', 'Linux'],
#   'Release': 'September 26, 2005',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Day_of_Defeat:_Source',
#   'Metascore': '80',
#   'User Score': '9.0'},
#  {'Name': 'Half-Life 2: Lost Coast',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_2_Lost_Coast_header.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Series': 'Half-Life',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows', 'OS X', 'Linux'],
#   'Release': 'October 27, 2005',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life_2:_Lost_Coast',
#   'Metascore': 'N/A',
#   'User Score': '7.9'},
#  {'Name': 'Half-Life 2: Episode One',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_2_-_Episode_One.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Writer(s)': ['Erik Wolpaw', 'Chet Faliszek'],
#   'Composer(s)': 'Kelly Bailey',
#   'Series': 'Half-Life',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows',
#    'Xbox 360',
#    'PlayStation 3',
#    'Mac OS X',
#    'Linux',
#    'Android'],
#   'Release': 'June 01, 2006',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life_2:_Episode_One',
#   'Metascore': '87',
#   'User Score': '8.7'},
#  {'Name': 'Half-Life 2: Episode Two',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_2_Episode_Two_title.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Writer(s)': ['Erik Wolpaw', 'Chet Faliszek'],
#   'Composer(s)': 'Kelly Bailey',
#   'Series': 'Half-Life',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows', 'PlayStation 3', 'Xbox 360', 'Mac OS X', 'Linux'],
#   'Release': 'October 10, 2007',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life_2:_Episode_Two',
#   'Metascore': '90',
#   'User Score': '9.2'},
#  {'Name': 'Portal',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Portal_standalonebox.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': ['Valve'],
#   'Designer(s)': 'Kim Swift',
#   'Writer(s)': ['Erik Wolpaw', 'Chet Faliszek'],
#   'Composer(s)': ['Kelly Bailey', 'Mike Morasky'],
#   'Series': 'Portal',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows',
#    'PlayStation 3',
#    'Xbox 360',
#    'Mac OS X',
#    'Linux',
#    'Android',
#    'Nintendo Switch'],
#   'Release': 'October 10, 2007',
#   'Genre(s)': 'Puzzle-platform',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Portal_(video_game)',
#   'Metascore': '90',
#   'User Score': '9.2'},
#  {'Name': 'Team Fortress 2',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Tf2_standalonebox.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Designer(s)': ['John Cook', 'Robin Walker'],
#   'Composer(s)': 'Mike Morasky',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows', 'Xbox 360', 'PlayStation 3', 'Mac OS X', 'Linux'],
#   'Release': 'October 10, 2007',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Team_Fortress_2',
#   'Metascore': '92',
#   'User Score': '9.0'},
#  {'Name': 'The Orange Box',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Hltob-win-cover.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows',
#    'Xbox 360',
#    'PlayStation 3',
#    'Mac OS X',
#    'Linux'],
#   'Release': 'October 10, 2007',
#   'Genre(s)': 'Various',
#   'Mode(s)': ['Single player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/The_Orange_Box',
#   'Metascore': '96',
#   'User Score': '9.1'},
#  {'Name': 'Left 4 Dead',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Left4Dead_Windows_cover.jpg',
#   'Developer(s)': 'Valve South',
#   'Publisher(s)': 'Valve',
#   'Designer(s)': 'Mike Booth',
#   'Writer(s)': 'Chet Faliszek',
#   'Composer(s)': 'Mike Morasky',
#   'Series': 'Left 4 Dead',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows', 'Xbox 360', 'Mac OS X'],
#   'Release': 'November 17, 2008',
#   'Genre(s)': ['First-person shooter', 'survival horror'],
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Left_4_Dead',
#   'Metascore': '89',
#   'User Score': '9.0'},
#  {'Name': 'Left 4 Dead 2',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Left4Dead2.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Designer(s)': 'Michael Booth',
#   'Writer(s)': 'Chet Faliszek',
#   'Composer(s)': 'Mike Morasky',
#   'Series': 'Left 4 Dead',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows', 'Xbox 360', 'Mac OS X', 'Linux'],
#   'Release': 'November 17, 2009',
#   'Genre(s)': ['First-person shooter', 'survival horror'],
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Left_4_Dead_2',
#   'Metascore': '89',
#   'User Score': '8.4'},
#  {'Name': 'Alien Swarm',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Alien_Swarm_Header.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Composer(s)': 'Mike Morasky',
#   'Engine': 'Source',
#   'Platform(s)': 'Microsoft Windows',
#   'Release': 'July 19, 2010',
#   'Genre(s)': 'Top-down shooter',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Alien_Swarm',
#   'Metascore': '77',
#   'User Score': '8.2'},
#  {'Name': 'Portal 2',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Portal2cover.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Director(s)': 'Joshua Weier',
#   'Producer(s)': 'Gabe Newell',
#   'Artist(s)': ['Jeremy Bennett', 'Randy Lundeen'],
#   'Writer(s)': ['Erik Wolpaw', 'Jay Pinkerton', 'Chet Faliszek'],
#   'Composer(s)': 'Mike Morasky',
#   'Series': 'Portal',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows',
#    'Mac OS X',
#    'Linux',
#    'PlayStation 3',
#    'Xbox 360',
#    'Nintendo Switch'],
#   'Release': 'April 18, 2011',
#   'Genre(s)': 'Puzzle-platform',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Portal_2',
#   'Metascore': '95',
#   'User Score': '9.1'},
#  {'Name': 'Counter-Strike: Global Offensive',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:CSGOcoverMarch2020.jpg',
#   'Developer(s)': ['Valve', 'Hidden Path Entertainment'],
#   'Publisher(s)': 'Valve',
#   'Composer(s)': 'Mike Morasky',
#   'Series': 'Counter-Strike',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows',
#    'macOS',
#    'Linux',
#    'PlayStation 3',
#    'Xbox 360'],
#   'Release': 'August 21, 2012',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Counter-Strike:_Global_Offensive',
#   'Metascore': '83',
#   'User Score': '7.3'},
#  {'Name': 'Dota 2',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Dota_2_(Steam_2019).jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Designer(s)': 'IceFrog',
#   'Writer(s)': ['Marc Laidlaw', 'Ted Kosmatka', 'Kris Katz'],
#   'Composer(s)': ['Jason Hayes', 'Tim Larkin'],
#   'Series': 'Dota',
#   'Engine': 'Source 2',
#   'Platform(s)': ['Microsoft Windows', 'Linux', 'OS X'],
#   'Release': 'July 09, 2013',
#   'Genre(s)': 'MOBA',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Dota_2',
#   'Metascore': '90',
#   'User Score': '6.5'},
#  {'Name': 'The Lab',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:The_lab_logo.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Series': 'Portal',
#   'Engine': ['Unity'],
#   'Platform(s)': 'Windows',
#   'Release': 'April 05, 2016',
#   'Genre(s)': 'Action',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/The_Lab_(video_game)',
#   'Metascore': 'N/A',
#   'User Score': '8.5'},
#  {'Name': 'Artifact',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Artifact_poster.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Director(s)': 'Brandon Reinhart',
#   'Designer(s)': 'Richard Garfield',
#   'Programmer(s)': ['Brad Muir', 'Jeep Barnett', 'Bruno Carlucci'],
#   'Writer(s)': 'Steve Jaros',
#   'Composer(s)': 'Tim Larkin',
#   'Series': 'Dota',
#   'Engine': 'Source 2',
#   'Platform(s)': ['Windows', 'macOS', 'Linux'],
#   'Release': 'November 28, 2018',
#   'Genre(s)': 'Digital collectible card game',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Artifact_(video_game)',
#   'Metascore': '76',
#   'User Score': '2.2'},
#  {'Name': 'Dota Underlords',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Dota_Underlords_steam.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Series': 'Dota',
#   'Engine': 'Source 2',
#   'Platform(s)': ['Android', 'iOS', 'macOS', 'Microsoft Windows', 'Linux'],
#   'Release': 'February 25, 2020',
#   'Genre(s)': 'Auto battler',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Dota_Underlords',
#   'Metascore': 'N/A',
#   'User Score': '7.4'},
#  {'Name': 'Half-Life: Alyx',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_Alyx_Cover_Art.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Writer(s)': ['Jay Pinkerton', 'Sean Vanaman', 'Erik Wolpaw', 'Jake Rodkin'],
#   'Composer(s)': 'Mike Morasky',
#   'Series': 'Half-Life',
#   'Engine': 'Source 2',
#   'Platform(s)': ['Windows', 'Linux'],
#   'Release': 'March 23, 2020',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life:_Alyx',
#   'Metascore': '93',
#   'User Score': '9.2'},
#  {'Name': 'Aperture Desk Job',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Aperture_desk_job_logo.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Composer(s)': ['Mike Morasky'],
#   'Series': 'Portal',
#   'Engine': 'Source 2',
#   'Platform(s)': ['Windows', 'Linux'],
#   'Release': 'March 01, 2022',
#   'Genre(s)': 'Action',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Aperture_Desk_Job',
#   'Metascore': 'N/A',
#   'User Score': '8.6'},
#  {'Name': "Garry's Mod",
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Garry%27s_Mod_logo.svg',
#   'Developer(s)': 'Facepunch Studios',
#   'Publisher(s)': 'Valve',
#   'Designer(s)': 'Garry Newman',
#   'Programmer(s)': 'Garry Newman',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows', 'Mac OS X', 'Linux'],
#   'Release': 'November 29, 2006',
#   'Genre(s)': 'Sandbox',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Garry%27s_Mod',
#   'Metascore': 'N/A',
#   'User Score': '8.9'}]

# %%
import pandas as pd

valve_df = pd.DataFrame.from_dict(valve_games)
valve_df
# Out:
#                                 Name  \
# 0                          Half-Life
# 1              Team Fortress Classic
# 2                     Counter-Strike
# 3                      Day of Defeat
# 4     Counter-Strike: Condition Zero
# 5             Counter-Strike: Source
# 6                        Half-Life 2
# 7            Half-Life 2: Deathmatch
# 8              Day of Defeat: Source
# 9            Half-Life 2: Lost Coast
# 10          Half-Life 2: Episode One
# 11          Half-Life 2: Episode Two
# 12                            Portal
# 13                   Team Fortress 2
# 14                    The Orange Box
# 15                       Left 4 Dead
# 16                     Left 4 Dead 2
# 17                       Alien Swarm
# 18                          Portal 2
# 19  Counter-Strike: Global Offensive
# 20                            Dota 2
# 21                           The Lab
# 22                          Artifact
# 23                   Dota Underlords
# 24                   Half-Life: Alyx
# 25                 Aperture Desk Job
# 26                       Garry's Mod
#
#                                            Image_link  \
# 0   https://en.wikipedia.org/wiki/File:Half-Life_C...
# 1   https://en.wikipedia.org/wiki/File:Team_Fortre...
# 2   https://en.wikipedia.org/wiki/File:Counter-Str...
# 3   https://en.wikipedia.org/wiki/File:Day_of_Defe...
# 4        https://en.wikipedia.org/wiki/File:CZbox.jpg
# 5   https://en.wikipedia.org/wiki/File:Counter-Str...
# 6   https://en.wikipedia.org/wiki/File:Half-Life_2...
# 7   https://en.wikipedia.org/wiki/File:Half-Life_2...
# 8   https://en.wikipedia.org/wiki/File:DODSourceCo...
# 9   https://en.wikipedia.org/wiki/File:Half-Life_2...
# 10  https://en.wikipedia.org/wiki/File:Half-Life_2...
# 11  https://en.wikipedia.org/wiki/File:Half-Life_2...
# 12  https://en.wikipedia.org/wiki/File:Portal_stan...
# 13  https://en.wikipedia.org/wiki/File:Tf2_standal...
# 14  https://en.wikipedia.org/wiki/File:Hltob-win-c...
# 15  https://en.wikipedia.org/wiki/File:Left4Dead_W...
# 16  https://en.wikipedia.org/wiki/File:Left4Dead2.jpg
# 17  https://en.wikipedia.org/wiki/File:Alien_Swarm...
# 18  https://en.wikipedia.org/wiki/File:Portal2cove...
# 19  https://en.wikipedia.org/wiki/File:CSGOcoverMa...
# 20  https://en.wikipedia.org/wiki/File:Dota_2_(Ste...
# 21  https://en.wikipedia.org/wiki/File:The_lab_log...
# 22  https://en.wikipedia.org/wiki/File:Artifact_po...
# 23  https://en.wikipedia.org/wiki/File:Dota_Underl...
# 24  https://en.wikipedia.org/wiki/File:Half-Life_A...
# 25  https://en.wikipedia.org/wiki/File:Aperture_de...
# 26  https://en.wikipedia.org/wiki/File:Garry%27s_M...
#
#                                          Developer(s)            Publisher(s)  \
# 0                                               Valve          Sierra Studios
# 1                                               Valve        [Sierra Studios]
# 2                                               Valve        [Sierra Studios]
# 3                                               Valve            [Activision]
# 4   [Ritual Entertainment, Turtle Rock Studios, Va...  [Sierra Entertainment]
# 5                        [Valve, Turtle Rock Studios]                   Valve
# 6                                               Valve                 [Valve]
# 7                                               Valve                   Valve
# 8                                               Valve                   Valve
# 9                                               Valve                   Valve
# 10                                              Valve                   Valve
# 11                                              Valve                   Valve
# 12                                              Valve                 [Valve]
# 13                                              Valve                   Valve
# 14                                              Valve                   Valve
# 15                                        Valve South                   Valve
# 16                                              Valve                   Valve
# 17                                              Valve                   Valve
# 18                                              Valve                   Valve
# 19                 [Valve, Hidden Path Entertainment]                   Valve
# 20                                              Valve                   Valve
# 21                                              Valve                   Valve
# 22                                              Valve                   Valve
# 23                                              Valve                   Valve
# 24                                              Valve                   Valve
# 25                                              Valve                   Valve
# 26                                  Facepunch Studios                   Valve
#
#                                             Writer(s)  \
# 0                                        Marc Laidlaw
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                        Marc Laidlaw
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                       [Erik Wolpaw, Chet Faliszek]
# 11                       [Erik Wolpaw, Chet Faliszek]
# 12                       [Erik Wolpaw, Chet Faliszek]
# 13                                                NaN
# 14                                                NaN
# 15                                      Chet Faliszek
# 16                                      Chet Faliszek
# 17                                                NaN
# 18        [Erik Wolpaw, Jay Pinkerton, Chet Faliszek]
# 19                                                NaN
# 20            [Marc Laidlaw, Ted Kosmatka, Kris Katz]
# 21                                                NaN
# 22                                        Steve Jaros
# 23                                                NaN
# 24  [Jay Pinkerton, Sean Vanaman, Erik Wolpaw, Jak...
# 25                                                NaN
# 26                                                NaN
#
#                      Composer(s)          Series    Engine  \
# 0                   Kelly Bailey       Half-Life   GoldSrc
# 1                            NaN             NaN   GoldSrc
# 2                            NaN  Counter-Strike   GoldSrc
# 3         Michael Gordon Shapiro             NaN   GoldSrc
# 4                            NaN  Counter-Strike   GoldSrc
# 5                            NaN  Counter-Strike    Source
# 6                   Kelly Bailey       Half-Life    Source
# 7                            NaN       Half-Life    Source
# 8                      Dan Haigh             NaN    Source
# 9                            NaN       Half-Life    Source
# 10                  Kelly Bailey       Half-Life    Source
# 11                  Kelly Bailey       Half-Life    Source
# 12  [Kelly Bailey, Mike Morasky]          Portal    Source
# 13                  Mike Morasky             NaN    Source
# 14                           NaN             NaN    Source
# 15                  Mike Morasky     Left 4 Dead    Source
# 16                  Mike Morasky     Left 4 Dead    Source
# 17                  Mike Morasky             NaN    Source
# 18                  Mike Morasky          Portal    Source
# 19                  Mike Morasky  Counter-Strike    Source
# 20     [Jason Hayes, Tim Larkin]            Dota  Source 2
# 21                           NaN          Portal   [Unity]
# 22                    Tim Larkin            Dota  Source 2
# 23                           NaN            Dota  Source 2
# 24                  Mike Morasky       Half-Life  Source 2
# 25                [Mike Morasky]          Portal  Source 2
# 26                           NaN             NaN    Source
#
#                                           Platform(s)             Release  \
# 0               [Windows, PlayStation 2, OS X, Linux]   November 19, 1998
# 1                    [Microsoft Windows, OS X, Linux]      April 07, 1999
# 2                        [Windows, Xbox, OS X, Linux]   November 09, 2000
# 3                    [Microsoft Windows, OS X, Linux]        May 06, 2003
# 4                              [Windows, OS X, Linux]      March 23, 2004
# 5                          [Windows, Mac OS X, Linux]    October 07, 2004
# 6   [Windows, Xbox, Xbox 360, PlayStation 3, Mac O...   November 16, 2004
# 7                [Microsoft Windows, Mac OS X, Linux]   November 30, 2004
# 8                [Microsoft Windows, Mac OS X, Linux]  September 26, 2005
# 9                    [Microsoft Windows, OS X, Linux]    October 27, 2005
# 10  [Windows, Xbox 360, PlayStation 3, Mac OS X, L...       June 01, 2006
# 11  [Windows, PlayStation 3, Xbox 360, Mac OS X, L...    October 10, 2007
# 12  [Windows, PlayStation 3, Xbox 360, Mac OS X, L...    October 10, 2007
# 13  [Windows, Xbox 360, PlayStation 3, Mac OS X, L...    October 10, 2007
# 14  [Microsoft Windows, Xbox 360, PlayStation 3, M...    October 10, 2007
# 15            [Microsoft Windows, Xbox 360, Mac OS X]   November 17, 2008
# 16     [Microsoft Windows, Xbox 360, Mac OS X, Linux]   November 17, 2009
# 17                                  Microsoft Windows       July 19, 2010
# 18  [Windows, Mac OS X, Linux, PlayStation 3, Xbox...      April 18, 2011
# 19  [Microsoft Windows, macOS, Linux, PlayStation ...     August 21, 2012
# 20                   [Microsoft Windows, Linux, OS X]       July 09, 2013
# 21                                            Windows      April 05, 2016
# 22                            [Windows, macOS, Linux]   November 28, 2018
# 23    [Android, iOS, macOS, Microsoft Windows, Linux]   February 25, 2020
# 24                                   [Windows, Linux]      March 23, 2020
# 25                                   [Windows, Linux]      March 01, 2022
# 26               [Microsoft Windows, Mac OS X, Linux]   November 29, 2006
#
#                                    Genre(s)                       Mode(s)  \
# 0                      First-person shooter  [Single-player, multiplayer]
# 1                      First-person shooter                   Multiplayer
# 2                      First-person shooter                   Multiplayer
# 3                      First-person shooter                   Multiplayer
# 4                      First-person shooter  [Single-player, multiplayer]
# 5                      First-person shooter                   Multiplayer
# 6                      First-person shooter                 Single-player
# 7                      First-person shooter                   Multiplayer
# 8                      First-person shooter                   Multiplayer
# 9                      First-person shooter                 Single-player
# 10                     First-person shooter                 Single-player
# 11                     First-person shooter                 Single-player
# 12                          Puzzle-platform                 Single-player
# 13                     First-person shooter  [Single-player, multiplayer]
# 14                                  Various  [Single player, multiplayer]
# 15  [First-person shooter, survival horror]  [Single-player, multiplayer]
# 16  [First-person shooter, survival horror]  [Single-player, multiplayer]
# 17                         Top-down shooter  [Single-player, multiplayer]
# 18                          Puzzle-platform  [Single-player, multiplayer]
# 19                     First-person shooter                   Multiplayer
# 20                                     MOBA                   Multiplayer
# 21                                   Action                 Single-player
# 22            Digital collectible card game                   Multiplayer
# 23                             Auto battler  [Single-player, multiplayer]
# 24                     First-person shooter                 Single-player
# 25                                   Action                 Single-player
# 26                                  Sandbox  [Single-player, multiplayer]
#
#                                                Source Metascore User Score  \
# 0   https://en.wikipedia.org/wiki/Half-Life_(video...        96        9.1
# 1   https://en.wikipedia.org/wiki/Team_Fortress_Cl...       N/A        7.2
# 2   https://en.wikipedia.org/wiki/Counter-Strike_(...        88        9.2
# 3         https://en.wikipedia.org/wiki/Day_of_Defeat        79        9.0
# 4   https://en.wikipedia.org/wiki/Counter-Strike:_...        65        8.7
# 5   https://en.wikipedia.org/wiki/Counter-Strike:_...        88        8.9
# 6           https://en.wikipedia.org/wiki/Half-Life_2        96        9.2
# 7   https://en.wikipedia.org/wiki/Half-Life_2:_Dea...       N/A        7.3
# 8   https://en.wikipedia.org/wiki/Day_of_Defeat:_S...        80        9.0
# 9   https://en.wikipedia.org/wiki/Half-Life_2:_Los...       N/A        7.9
# 10  https://en.wikipedia.org/wiki/Half-Life_2:_Epi...        87        8.7
# 11  https://en.wikipedia.org/wiki/Half-Life_2:_Epi...        90        9.2
# 12  https://en.wikipedia.org/wiki/Portal_(video_game)        90        9.2
# 13      https://en.wikipedia.org/wiki/Team_Fortress_2        92        9.0
# 14       https://en.wikipedia.org/wiki/The_Orange_Box        96        9.1
# 15          https://en.wikipedia.org/wiki/Left_4_Dead        89        9.0
# 16        https://en.wikipedia.org/wiki/Left_4_Dead_2        89        8.4
# 17          https://en.wikipedia.org/wiki/Alien_Swarm        77        8.2
# 18             https://en.wikipedia.org/wiki/Portal_2        95        9.1
# 19  https://en.wikipedia.org/wiki/Counter-Strike:_...        83        7.3
# 20               https://en.wikipedia.org/wiki/Dota_2        90        6.5
# 21  https://en.wikipedia.org/wiki/The_Lab_(video_g...       N/A        8.5
# 22  https://en.wikipedia.org/wiki/Artifact_(video_...        76        2.2
# 23      https://en.wikipedia.org/wiki/Dota_Underlords       N/A        7.4
# 24      https://en.wikipedia.org/wiki/Half-Life:_Alyx        93        9.2
# 25    https://en.wikipedia.org/wiki/Aperture_Desk_Job       N/A        8.6
# 26        https://en.wikipedia.org/wiki/Garry%27s_Mod       N/A        8.9
#
#                   Designer(s)                        Artist(s)  \
# 0                         NaN                              NaN
# 1   [John Cook, Robin Walker]                              NaN
# 2      [Minh Le, Jess Cliffe]                              NaN
# 3                         NaN                              NaN
# 4                         NaN                              NaN
# 5                         NaN                              NaN
# 6                         NaN                   Viktor Antonov
# 7                         NaN                              NaN
# 8                         NaN                              NaN
# 9                         NaN                              NaN
# 10                        NaN                              NaN
# 11                        NaN                              NaN
# 12                  Kim Swift                              NaN
# 13  [John Cook, Robin Walker]                              NaN
# 14                        NaN                              NaN
# 15                 Mike Booth                              NaN
# 16              Michael Booth                              NaN
# 17                        NaN                              NaN
# 18                        NaN  [Jeremy Bennett, Randy Lundeen]
# 19                        NaN                              NaN
# 20                    IceFrog                              NaN
# 21                        NaN                              NaN
# 22           Richard Garfield                              NaN
# 23                        NaN                              NaN
# 24                        NaN                              NaN
# 25                        NaN                              NaN
# 26               Garry Newman                              NaN
#
#          Director(s)  Producer(s)                              Programmer(s)
# 0                NaN          NaN                                        NaN
# 1                NaN          NaN                                        NaN
# 2                NaN          NaN                                        NaN
# 3                NaN          NaN                                        NaN
# 4                NaN          NaN                                        NaN
# 5                NaN          NaN                                        NaN
# 6                NaN          NaN                                        NaN
# 7                NaN          NaN                                        NaN
# 8                NaN          NaN                                        NaN
# 9                NaN          NaN                                        NaN
# 10               NaN          NaN                                        NaN
# 11               NaN          NaN                                        NaN
# 12               NaN          NaN                                        NaN
# 13               NaN          NaN                                        NaN
# 14               NaN          NaN                                        NaN
# 15               NaN          NaN                                        NaN
# 16               NaN          NaN                                        NaN
# 17               NaN          NaN                                        NaN
# 18      Joshua Weier  Gabe Newell                                        NaN
# 19               NaN          NaN                                        NaN
# 20               NaN          NaN                                        NaN
# 21               NaN          NaN                                        NaN
# 22  Brandon Reinhart          NaN  [Brad Muir, Jeep Barnett, Bruno Carlucci]
# 23               NaN          NaN                                        NaN
# 24               NaN          NaN                                        NaN
# 25               NaN          NaN                                        NaN
# 26               NaN          NaN                               Garry Newman

# %%
blizzard_df = pd.DataFrame.from_dict(blizzard_games)
blizzard_df
# Out:
#                                 Name  \
# 0                         RPM Racing
# 1                   The Lost Vikings
# 2                Rock n' Roll Racing
# 3   The Death and Return of Superman
# 4                        Blackthorne
# 5            Warcraft: Orcs & Humans
# 6          Justice League Task Force
# 7     Warcraft II: Tides of Darkness
# 8                             Diablo
# 9                     Lost Vikings 2
# 10                         StarCraft
# 11                         Diablo II
# 12      Warcraft III: Reign of Chaos
# 13                 World of Warcraft
# 14    StarCraft II: Wings of Liberty
# 15                        Diablo III
# 16   Hearthstone: Heroes of Warcraft
# 17               Heroes of the Storm
# 18                         Overwatch
# 19                   Diablo Immortal
#
#                                            Image_link  \
# 0   https://en.wikipedia.org/wiki/File:RPM_Racing_...
# 1   https://en.wikipedia.org/wiki/File:The_Lost_Vi...
# 2   https://en.wikipedia.org/wiki/File:Rock_N%27_R...
# 3   https://en.wikipedia.org/wiki/File:The_Death_a...
# 4   https://en.wikipedia.org/wiki/File:Blackthorne...
# 5   https://en.wikipedia.org/wiki/File:Warcraft_-_...
# 6   https://en.wikipedia.org/wiki/File:Justice_Lea...
# 7   https://en.wikipedia.org/wiki/File:Warcraft-2-...
# 8   https://en.wikipedia.org/wiki/File:Diablo_Cove...
# 9   https://en.wikipedia.org/wiki/File:Lost_Viking...
# 10  https://en.wikipedia.org/wiki/File:StarCraft_b...
# 11  https://en.wikipedia.org/wiki/File:Diablo_II_C...
# 12  https://en.wikipedia.org/wiki/File:WarcraftIII...
# 13  https://en.wikipedia.org/wiki/File:World_of_Wa...
# 14  https://en.wikipedia.org/wiki/File:StarCraft_I...
# 15  https://en.wikipedia.org/wiki/File:Diablo_III_...
# 16  https://en.wikipedia.org/wiki/File:Hearthstone...
# 17  https://en.wikipedia.org/wiki/File:Heroes_of_t...
# 18  https://en.wikipedia.org/wiki/File:Overwatch_c...
# 19  https://en.wikipedia.org/wiki/File:Diablo_Immo...
#
#                                          Developer(s)  \
# 0                                   Silicon & Synapse
# 1                                   Silicon & Synapse
# 2                                [Software Creations]
# 3                   [Blizzard Entertainment, Sunsoft]
# 4                              Blizzard Entertainment
# 5                              Blizzard Entertainment
# 6   [Sunsoft, Super NES, Blizzard Entertainment, M...
# 7                              Blizzard Entertainment
# 8                                      Blizzard North
# 9             [Blizzard Entertainment, Beam Software]
# 10                             Blizzard Entertainment
# 11                                     Blizzard North
# 12                             Blizzard Entertainment
# 13                             Blizzard Entertainment
# 14                             Blizzard Entertainment
# 15                             Blizzard Entertainment
# 16                             Blizzard Entertainment
# 17                             Blizzard Entertainment
# 18                             Blizzard Entertainment
# 19                  [Blizzard Entertainment, NetEase]
#
#                                          Publisher(s)  \
# 0   [Interplay Productions, Victor Musical Industr...
# 1   [Interplay Productions, T&E Soft, Blizzard Ent...
# 2   [Interplay Productions, Namco, Blizzard Entert...
# 3                                             Sunsoft
# 4                               Interplay Productions
# 5                          [EU:Interplay Productions]
# 6                               Acclaim Entertainment
# 7                               Davidson & Associates
# 8      [Blizzard Entertainment,Davidson & Associates]
# 9                               Interplay Productions
# 10                             Blizzard Entertainment
# 11                             Blizzard Entertainment
# 12                             Blizzard Entertainment
# 13                             Blizzard Entertainment
# 14                             Blizzard Entertainment
# 15                             Blizzard Entertainment
# 16                             Blizzard Entertainment
# 17                             Blizzard Entertainment
# 18                             Blizzard Entertainment
# 19                             Blizzard Entertainment
#
#                                       Producer(s)  \
# 0                                 Michael Quarles
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4            [Ronald Millar Sr., Matthew Findley]
# 5                     [Bill Roper, Patrick Wyatt]
# 6                                             NaN
# 7   [Sam Didier, Michael Morhaime, Patrick Wyatt]
# 8                                      Bill Roper
# 9                                Feargus Urquhart
# 10                                            NaN
# 11                  [Mark Kern, Kenneth Williams]
# 12                                   Chris Sigaty
# 13                                            NaN
# 14                                   Chris Sigaty
# 15                                  Alex Mayberry
# 16                                            NaN
# 17                                    Kaéo Milker
# 18                                            NaN
# 19                                            NaN
#
#                                         Programmer(s)  \
# 0                                         Allen Adham
# 1                                                 NaN
# 2             [Bob Fitch, Patrick Wyatt, Ayman Adham]
# 3   [James Edward Anhalt III, Allen Adham, Bob Fitch]
# 4                   [Frank Pearce Jr., Patrick Wyatt]
# 5   [Bob Fitch, Jesse McReynolds, Michael Morhaime...
# 6                                                 NaN
# 7     [Bob Fitch, Jesse McReynolds, Michael Morhaime]
# 8                                        David Brevik
# 9                                       James Phinney
# 10                                                NaN
# 11                                          Rick Seis
# 12                                                NaN
# 13                                                NaN
# 14                           [Carl Chimes, Bob Fitch]
# 15                                       Jason Regier
# 16                                                NaN
# 17                                                NaN
# 18                       [Mike Elliott, John LeFleur]
# 19                                                NaN
#
#                                             Artist(s)  \
# 0                                          Rob Nesler
# 1                                                 NaN
# 2   [Samwise Didier, Ronald Millar Sr., Joeyray Hall]
# 3   [Samwise Didier, David Berggren, Roman Kenney,...
# 4   [Roman Kenney, Stuart Rose, Jason Magness, Ron...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                      Michio Okamura
# 9                                      Samwise Didier
# 10                                                NaN
# 11                                         Phil Shenk
# 12                                                NaN
# 13                                                NaN
# 14                                     Samwise Didier
# 15                                 Christian Lichtner
# 16                                                NaN
# 17                                                NaN
# 18                     [William Petras, Arnold Tsang]
# 19                                                NaN
#
#                                           Composer(s)  \
# 0                              George Alistair Sanger
# 1                                      Charles Deenen
# 2                         Tim Follin and Geoff Follin
# 3                  [Michael Morhaime, Glenn Stafford]
# 4                                      Glenn Stafford
# 5                                       Gregory Alper
# 6                       [Matt Uelmen, Glenn Stafford]
# 7                                      Glenn Stafford
# 8                                         Matt Uelmen
# 9                                      Glenn Stafford
# 10  [Derek Duke, Jason Hayes, Glenn Stafford, Trac...
# 11                                        Matt Uelmen
# 12        [Tracy W. Bush, Derek Duke, Glenn Stafford]
# 13                                        Jason Hayes
# 14  [Derek Duke, Glenn Stafford, Russell Brower, N...
# 15                                     Russell Brower
# 16                                    Peter McConnell
# 17                      [Glenn Stafford, Jason Hayes]
# 18                                         Derek Duke
# 19                                                NaN
#
#                                           Platform(s)             Release  \
# 0   [Super NES, Windows, Switch, PlayStation 4, Xb...      March 19, 1992
# 1   [Super Nintendo, Genesis, Amiga, MS-DOS, Amiga...      April 29, 1993
# 2   [Super NES, Mega Drive/Genesis, Game Boy Advan...       June 04, 1993
# 3                           [Super NES, Sega Genesis]                None
# 4   [SNES, MS-DOS, Sega 32X, Classic Mac OS, Game ...   February 20, 2021
# 5                            [MS-DOS, Classic Mac OS]   November 15, 1994
# 6                                [Genesis, Super NES]  September 01, 1995
# 7   [MS-DOS, Classic Mac OS, Saturn, PlayStation, ...   December 09, 1995
# 8            [Microsoft Windows, PlayStation, Mac OS]    January 03, 1997
# 9   [Super NES, MS-DOS, Windows, Saturn, PlayStati...   February 27, 1997
# 10   [Microsoft Windows, Classic Mac OS, Nintendo 64]      March 31, 1998
# 11         [Microsoft Windows, Classic Mac OS, macOS]       June 29, 2000
# 12      [Microsoft Windows, Classic Mac OS, Mac OS X]       July 03, 2002
# 13                         [Microsoft Windows, macOS]   November 23, 2004
# 14                         [Microsoft Windows, macOS]       July 27, 2010
# 15  [Microsoft Windows, OS X, PlayStation 3, Xbox ...        May 15, 2012
# 16           [Microsoft Windows, macOS, iOS, Android]      March 11, 2014
# 17                         [Microsoft Windows, macOS]       June 02, 2015
# 18  [Microsoft Windows, PlayStation 4, Xbox One, N...        May 24, 2016
# 19                            [Android, iOS, Windows]       June 02, 2022
#
#                                              Genre(s)  \
# 0                                              Racing
# 1                                     Puzzle-platform
# 2                                              Racing
# 3                                         Beat 'em up
# 4                                            Platform
# 5                                  Real-time strategy
# 6                                            Fighting
# 7                                  Real-time strategy
# 8                                 Action role-playing
# 9                                     Puzzle-platform
# 10                                 Real-time strategy
# 11              [Action role-playing, hack and slash]
# 12                                 Real-time strategy
# 13          Massively multiplayer online role-playing
# 14                                 Real-time strategy
# 15              [Action role-playing, hack and slash]
# 16                      Digital collectible card game
# 17                                               MOBA
# 18                               First-person shooter
# 19  [Action role-playing, Massively multiplayer on...
#
#                                   Mode(s)  \
# 0            [Single-player, multiplayer]
# 1            [Single-player, cooperative]
# 2            [Single-player, multiplayer]
# 3                           Single player
# 4                           Single-player
# 5            [Single-player, multiplayer]
# 6            [Single-player, multiplayer]
# 7            [Single-player, multiplayer]
# 8            [Single-player, multiplayer]
# 9   [Single-player, 2 player cooperative]
# 10           [Single-player, multiplayer]
# 11           [Single-player, multiplayer]
# 12           [Single-player, multiplayer]
# 13                            Multiplayer
# 14           [Single-player, multiplayer]
# 15           [Single-player, multiplayer]
# 16           [Single-player, multiplayer]
# 17                            Multiplayer
# 18                            Multiplayer
# 19                            Multiplayer
#
#                                                Source Metascore User Score  \
# 0            https://en.wikipedia.org/wiki/RPM_Racing       N/A        N/A
# 1      https://en.wikipedia.org/wiki/The_Lost_Vikings       N/A        N/A
# 2   https://en.wikipedia.org/wiki/Rock_n%27_Roll_R...       N/A        N/A
# 3   https://en.wikipedia.org/wiki/The_Death_and_Re...       N/A        N/A
# 4           https://en.wikipedia.org/wiki/Blackthorne       N/A        N/A
# 5   https://en.wikipedia.org/wiki/Warcraft:_Orcs_%...       N/A        N/A
# 6   https://en.wikipedia.org/wiki/Justice_League_T...       N/A        N/A
# 7   https://en.wikipedia.org/wiki/Warcraft_II:_Tid...       N/A        9.0
# 8   https://en.wikipedia.org/wiki/Diablo_(video_game)        94        8.6
# 9    https://en.wikipedia.org/wiki/The_Lost_Vikings_2       N/A        N/A
# 10  https://en.wikipedia.org/wiki/StarCraft_(video...        88        9.1
# 11            https://en.wikipedia.org/wiki/Diablo_II        88        8.7
# 12  https://en.wikipedia.org/wiki/Warcraft_III:_Re...        92        9.2
# 13    https://en.wikipedia.org/wiki/World_of_Warcraft        93        7.4
# 14  https://en.wikipedia.org/wiki/StarCraft_II:_Wi...        93        8.3
# 15           https://en.wikipedia.org/wiki/Diablo_III        88        4.1
# 16          https://en.wikipedia.org/wiki/Hearthstone        88        5.7
# 17  https://en.wikipedia.org/wiki/Heroes_of_the_Storm        86        6.3
# 18            https://en.wikipedia.org/wiki/Overwatch        91        6.4
# 19      https://en.wikipedia.org/wiki/Diablo_Immortal       N/A        N/A
#
#                                           Designer(s)  \
# 0                                                 NaN
# 1                                          Ron Millar
# 2                                        Alan Pavlish
# 3                                       Dan MacArthur
# 4                                   Ronald Millar Sr.
# 5                                                 NaN
# 6                                                 NaN
# 7                                          Ron Millar
# 8   [David Brevik, Erich Schaefer, Max Schaefer, E...
# 9                                          Ron Millar
# 10                      [Chris Metzen, James Phinney]
# 11       [David Brevik, Erich Schaefer, Max Schaefer]
# 12                                          Rob Pardo
# 13              [Rob Pardo, Jeff Kaplan, Tom Chilton]
# 14                                     Dustin Browder
# 15                    [Kevin Martens, David M. Adams]
# 16                      [Derek Sakamoto, Mike Donais]
# 17                                                NaN
# 18      [Jeremy Craig, Michael Elliott, Scott Mercer]
# 19                                                NaN
#
#                                             Writer(s)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   [Micky Neilson, Ronald Millar Sr., Frank Pearc...
# 5                                                 NaN
# 6                                                 NaN
# 7                                        Chris Metzen
# 8   [Chris Metzen, Bill Roper, Eric Sexton, Erich ...
# 9                                                 NaN
# 10                                                NaN
# 11  [Kurt Beaver, Stieg Hedlund, Matthew Household...
# 12                                       Chris Metzen
# 13                                                NaN
# 14   [Chris Metzen, Andrew Chambers, Brian Kindregan]
# 15                                       Chris Metzen
# 16                                                NaN
# 17                                                NaN
# 18                         [Michael Chu, Alyssa Wong]
# 19                                                NaN
#
#                                      Director(s)     Series Engine
# 0                                            NaN        NaN    NaN
# 1                                            NaN        NaN    NaN
# 2                                            NaN        NaN    NaN
# 3                                            NaN        NaN    NaN
# 4                                            NaN        NaN    NaN
# 5                                  Patrick Wyatt   Warcraft    NaN
# 6                                            NaN        NaN    NaN
# 7                                            NaN   Warcraft    NaN
# 8                                            NaN     Diablo    NaN
# 9                                            NaN        NaN    NaN
# 10                                           NaN  StarCraft    NaN
# 11  [David Brevik, Erich Schaefer, Max Schaefer]     Diablo    NaN
# 12                              Frank Pearce Jr.   Warcraft    NaN
# 13                                           NaN   Warcraft    NaN
# 14                                           NaN  StarCraft    NaN
# 15                                    Jay Wilson     Diablo    NaN
# 16         [Ben Brode, Jason Chayes, Eric Dodds]   Warcraft  Unity
# 17                 [Dustin Browder, Alan Dabiri]        NaN    NaN
# 18     [Jeff Kaplan, Chris Metzen, Aaron Keller]        NaN    NaN
# 19                                   Wyatt Cheng     Diablo    NaN

# %%
valve_df.to_csv('valve_cleaned_csv.csv')
blizzard_df.to_csv('blizzard_cleaned_csv.csv')

# %% [markdown]
# Things to clean:
# - Remove references [a] [1] etc
# - Convert from all li in one string to list of strings
# - In release, format from '\nNovember 19, 1998\n Windows' to 'November 19, 1998 (Windows)'

# %% [markdown]
# Tasks:
# - Scrape both websites
# - Convert to dictionary
# - Convert to pandas
# - Do some EDA
# - Make insights
