# %% [markdown]
# ##### Goal: Find out which game company has a higher overall rating (Valve vs Blizzard)

# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
import re

def name_to_link(name):
    # matches when a char is not a-zA-Z or 0-9 or "_"
    alphanumeric_re = r'\W'
    
    name = name.lower()
    name = name.replace(' ', '_')
    # remove matches of non alphanumeric or "_"
    name = re.sub(alphanumeric_re, '', name)
    name = name.replace('_', '-')
    
    return name

print(name_to_link('Garry\'s Mod'))
print(name_to_link('Half life 2: Lost Coast'))
# Out:
# garrys-mod
# half-life-2-lost-coast

# %%
# eg. https://www.metacritic.com/game/pc/garrys-mod, https://www.metacritic.com/game/pc/half-life
# preprocessing tbd: use name, change to lowercase, take out ' : etc symbols,  

names = ['Half life 2: Lost Coast', 'Garry\'s Mod']
for name in names:
    name = name_to_link(name)
    url = f'https://www.metacritic.com/game/pc/{name}'

    user_agent = {'User-agent': 'Mozilla/5.0'}
    response = requests.get(url, headers = user_agent)
    soup = bs(response.content)
    score = soup.select('.metascore_anchor')
    print(url)
    print(score)
# Out:
# https://www.metacritic.com/game/pc/half-life-2-lost-coast
# [<a class="metascore_anchor" href="/game/pc/half-life-2-lost-coast/user-reviews">
# <div class="metascore_w user large game positive">7.9</div>
# </a>, <a class="metascore_anchor" href="/game/pc/elden-ring">
# <span class="metascore_w small game positive">94</span>
# </a>, <a class="metascore_anchor" href="/game/pc/god-of-war">
# <span class="metascore_w small game positive">93</span>
# </a>, <a class="metascore_anchor" href="/game/pc/final-fantasy-xiv-endwalker">
# <span class="metascore_w small game positive">92</span>
# </a>, <a class="metascore_anchor" href="/game/pc/the-stanley-parable-ultra-deluxe">
# <span class="metascore_w small game positive">91</span>
# </a>, <a class="metascore_anchor" href="/game/pc/rogue-legacy-2">
# <span class="metascore_w small game positive">90</span>
# </a>, <a class="metascore_anchor" href="/game/pc/norco">
# <span class="metascore_w small game positive">88</span>
# </a>, <a class="metascore_anchor" href="/game/pc/final-fantasy-vi-pixel-remaster">
# <span class="metascore_w small game positive">88</span>
# </a>, <a class="metascore_anchor" href="/game/pc/monster-hunter-rise">
# <span class="metascore_w small game positive">87</span>
# </a>, <a class="metascore_anchor" href="/game/pc/olliolli-world">
# <span class="metascore_w small game positive">87</span>
# </a>, <a class="metascore_anchor" href="/game/pc/total-war-warhammer-iii">
# <span class="metascore_w small game positive">86</span>
# </a>, <a class="metascore_anchor" href="/game/pc/final-fantasy-vii-remake-intergrade">
# <span class="metascore_w small game positive">86</span>
# </a>, <a class="metascore_anchor" href="/game/pc/tunic">
# <span class="metascore_w small game positive">85</span>
# </a>, <a class="metascore_anchor" href="/game/pc/halo-infinite">
# <span class="metascore_w small game positive">80</span>
# </a>, <a class="metascore_anchor" href="/game/pc/gtfo">
# <span class="metascore_w small game positive">78</span>
# </a>, <a class="metascore_anchor" href="/game/pc/wytchwood">
# <span class="metascore_w small game positive">78</span>
# </a>, <a class="metascore_anchor" href="/game/pc/dying-light-2-stay-human">
# <span class="metascore_w small game positive">77</span>
# </a>, <a class="metascore_anchor" href="/game/pc/martha-is-dead">
# <span class="metascore_w small game mixed">74</span>
# </a>, <a class="metascore_anchor" href="/game/pc/thunder-tier-one">
# <span class="metascore_w small game mixed">65</span>
# </a>, <a class="metascore_anchor" href="/game/pc/praey-for-the-gods">
# <span class="metascore_w small game mixed">61</span>
# </a>, <a class="metascore_anchor" href="/game/pc/babylons-fall">
# <span class="metascore_w small game negative">46</span>
# </a>]
# https://www.metacritic.com/game/pc/garrys-mod
# [<a class="metascore_anchor" href="/game/pc/garrys-mod/user-reviews">
# <div class="metascore_w user large game positive">8.9</div>
# </a>, <a class="metascore_anchor" href="/game/pc/elden-ring">
# <span class="metascore_w small game positive">94</span>
# </a>, <a class="metascore_anchor" href="/game/pc/god-of-war">
# <span class="metascore_w small game positive">93</span>
# </a>, <a class="metascore_anchor" href="/game/pc/final-fantasy-xiv-endwalker">
# <span class="metascore_w small game positive">92</span>
# </a>, <a class="metascore_anchor" href="/game/pc/the-stanley-parable-ultra-deluxe">
# <span class="metascore_w small game positive">91</span>
# </a>, <a class="metascore_anchor" href="/game/pc/rogue-legacy-2">
# <span class="metascore_w small game positive">90</span>
# </a>, <a class="metascore_anchor" href="/game/pc/norco">
# <span class="metascore_w small game positive">88</span>
# </a>, <a class="metascore_anchor" href="/game/pc/final-fantasy-vi-pixel-remaster">
# <span class="metascore_w small game positive">88</span>
# </a>, <a class="metascore_anchor" href="/game/pc/monster-hunter-rise">
# <span class="metascore_w small game positive">87</span>
# </a>, <a class="metascore_anchor" href="/game/pc/olliolli-world">
# <span class="metascore_w small game positive">87</span>
# </a>, <a class="metascore_anchor" href="/game/pc/total-war-warhammer-iii">
# <span class="metascore_w small game positive">86</span>
# </a>, <a class="metascore_anchor" href="/game/pc/final-fantasy-vii-remake-intergrade">
# <span class="metascore_w small game positive">86</span>
# </a>, <a class="metascore_anchor" href="/game/pc/tunic">
# <span class="metascore_w small game positive">85</span>
# </a>, <a class="metascore_anchor" href="/game/pc/halo-infinite">
# <span class="metascore_w small game positive">80</span>
# </a>, <a class="metascore_anchor" href="/game/pc/gtfo">
# <span class="metascore_w small game positive">78</span>
# </a>, <a class="metascore_anchor" href="/game/pc/wytchwood">
# <span class="metascore_w small game positive">78</span>
# </a>, <a class="metascore_anchor" href="/game/pc/dying-light-2-stay-human">
# <span class="metascore_w small game positive">77</span>
# </a>, <a class="metascore_anchor" href="/game/pc/martha-is-dead">
# <span class="metascore_w small game mixed">74</span>
# </a>, <a class="metascore_anchor" href="/game/pc/thunder-tier-one">
# <span class="metascore_w small game mixed">65</span>
# </a>, <a class="metascore_anchor" href="/game/pc/praey-for-the-gods">
# <span class="metascore_w small game mixed">61</span>
# </a>, <a class="metascore_anchor" href="/game/pc/babylons-fall">
# <span class="metascore_w small game negative">46</span>
# </a>]

# %%
valve_html = requests.get('https://en.wikipedia.org/wiki/List_of_Valve_games')
blizzard_html = requests.get('https://en.wikipedia.org/wiki/List_of_Blizzard_Entertainment_games')

# %%
soup = bs(valve_html.content)

contents = soup.prettify()

#print(contents)

# %%
games = soup.select('.wikitable i a')
game_path = games[0]['href']

game_path
# Out:
# '/wiki/Half-Life_(video_game)'

# %%
def get_game_links(url):
    html = requests.get(url)
    soup = bs(html.content)
    games = soup.select('.wikitable i a')
    games = soup.select('.wikitable .fn i a')
    game_links = []
    base_path = 'https://en.wikipedia.org'

    for game in games:
        # subdirectory example: "/wiki/Half-Life_(video_game)"
        game_subdirectory = game['href']
        path = base_path + game_subdirectory
        game_links.append(path)
    
    return game_links

get_game_links('https://en.wikipedia.org/wiki/List_of_Valve_games')
# Out:
# ['https://en.wikipedia.org/wiki/Half-Life_(video_game)',
#  'https://en.wikipedia.org/wiki/Team_Fortress_Classic',
#  'https://en.wikipedia.org/wiki/Counter-Strike_(video_game)',
#  'https://en.wikipedia.org/wiki/Day_of_Defeat',
#  'https://en.wikipedia.org/wiki/Counter-Strike:_Condition_Zero',
#  'https://en.wikipedia.org/wiki/Counter-Strike:_Source',
#  'https://en.wikipedia.org/wiki/Half-Life_2',
#  'https://en.wikipedia.org/wiki/Half-Life_2:_Deathmatch',
#  'https://en.wikipedia.org/wiki/Day_of_Defeat:_Source',
#  'https://en.wikipedia.org/wiki/Half-Life_2:_Lost_Coast',
#  'https://en.wikipedia.org/wiki/Half-Life_2:_Episode_One',
#  'https://en.wikipedia.org/wiki/Half-Life_2:_Episode_Two',
#  'https://en.wikipedia.org/wiki/Portal_(video_game)',
#  'https://en.wikipedia.org/wiki/Team_Fortress_2',
#  'https://en.wikipedia.org/wiki/The_Orange_Box',
#  'https://en.wikipedia.org/wiki/Left_4_Dead',
#  'https://en.wikipedia.org/wiki/Left_4_Dead_2',
#  'https://en.wikipedia.org/wiki/Alien_Swarm',
#  'https://en.wikipedia.org/wiki/Portal_2',
#  'https://en.wikipedia.org/wiki/Counter-Strike:_Global_Offensive',
#  'https://en.wikipedia.org/wiki/Dota_2',
#  'https://en.wikipedia.org/wiki/The_Lab_(video_game)',
#  'https://en.wikipedia.org/wiki/Artifact_(video_game)',
#  'https://en.wikipedia.org/wiki/Dota_Underlords',
#  'https://en.wikipedia.org/wiki/Half-Life:_Alyx',
#  'https://en.wikipedia.org/wiki/Aperture_Desk_Job',
#  'https://en.wikipedia.org/wiki/Garry%27s_Mod']

# %%
import re

def remove_ref(contents):
    # regular expression to find all matches with format [c] where c is any character eg. [a] or [1]
    reference = r'\[.\]'
    
    if type(contents) == str:
        matches = re.findall(reference, contents)
        # for each match, remove it from the string
        for match in matches:
            contents = contents.replace(match, '')
        return contents
    
    elif type(contents) == list:
        contents_list = []
        for my_string in contents:
            matches = re.findall(reference, my_string)
            for match in matches:
                my_string = my_string.replace(match, '')
            contents_list.append(my_string)
        return contents_list

# %%
remove_ref(['sadsada[a]', 'dassdsadpas[a]'])
# Out:
# ['sadsada', 'dassdsadpas']

# %%
def get_row_contents(row):
    """# to deal with platform
    if row.select('.plainlist ul li b'):
        full_list = row.select('.plainlist ul li')
        platform_date_list = []
        for i, item in enumerate(full_list):
            #print(item)
            #platform_name = "default platform"
            #date = "default date"
            if item.select('li b'):
                concat_platform = ""
                platforms_comma_separated = item.find_all('b')
                for j, platform in enumerate(platforms_comma_separated):
                    concat_platform += platform.get_text()
                    if (j < len(platforms_comma_separated)-1):
                        concat_platform += ", "
                platform_name = concat_platform
                #print(i, platform_name)
            else:
                date = item.get_text()
                #print(i, date)
            
            #print(i, platform_name, date)
            
            if (i % 2 == 1):
                platform_date_list.append(f'{platform_name}: {date}')
            #platform_date_list.append('something happening hahahahha')
        return platform_date_list"""
    # to handle releases
    # strip=True to remove whitespace chars (\n, xa0, etc)
    if row.select('li ul li'):
        return [li.get_text('', strip=True) for li in row.select('li ul li')]
    elif row.find('li'):
        return [li.get_text('', strip=True) for li in row.find_all('li')]
    #elif row.find('br'):
        #return [text for text in row.stripped_strings]
    elif "," in row.get_text():
        return [text.strip() for text in row.find('td', class_='infobox-data').get_text().split(',')]
    else:  
        return row.find('td', class_='infobox-data').get_text()

# %%
my_string = 'OS X, Linux'
my_string.split(',')
# Out:
# ['OS X', ' Linux']

# %%
my_string = 'Single-player, multiplayer'
my_string.split(',')
# Out:
# ['Single-player', ' multiplayer']

# %%
import re

def get_release_date(contents):
    date_re = r'[A-Za-z]+[ ]\d+,[ ]\d+'
    
    if type(contents) == str:
        match = re.search(date_re, contents)
        return match.group()
    elif type(contents) == list:
        for item in contents:
            match = re.search(date_re, item)
            if (match != None):
                return match.group()

get_release_date(['WW:September 26, 2005', 'WW:July 12, 2010', 'WW:March 14, 2013'])
# Out:
# 'September 26, 2005'

# %%
def get_info_box(url):
    game_html = requests.get(url)
    game_soup = bs(game_html.content)
    
    info_box = game_soup.find('table', class_='infobox')
    info_rows = info_box.find_all('tr')
    
    game_info = {}
    
    for i, row in enumerate(info_rows):
        # get title from infobox
        if row.select('.infobox-above'):
            game_info['Name'] = row.find('th').get_text()
        # get image link from infobox
        elif row.select('.infobox-image'):
            image_link = base_path + row.find('a')['href']
            game_info['Image_link'] = image_link
        else:
            label = row.find('th', class_='infobox-label').get_text()
            contents = get_row_contents(row)
            if (label == 'Release'):
                contents = get_release_date(contents)
                
            contents = remove_ref(contents)
            game_info[label] = contents
    
    game_info['Source'] = url
    
    return game_info
    
    
get_info_box('https://en.wikipedia.org/wiki/Team_Fortress_Classic')
# Out:
# {'Name': 'Team Fortress Classic',
#  'Image_link': 'https://en.wikipedia.org/wiki/File:Team_Fortress_Classic_box.jpg',
#  'Developer(s)': 'Valve',
#  'Publisher(s)': ['Sierra Studios', 'Valve (digital)'],
#  'Designer(s)': ['John Cook', 'Robin Walker'],
#  'Engine': 'GoldSrc',
#  'Platform(s)': ['Microsoft Windows', 'OS X', 'Linux'],
#  'Release': 'April 7, 1999',
#  'Genre(s)': 'First-person shooter',
#  'Mode(s)': 'Multiplayer',
#  'Source': 'https://en.wikipedia.org/wiki/Team_Fortress_Classic'}

# %%
def scrape_game_company(url):
    game_links = get_game_links(url)
    games_info = []
    for i, link in enumerate(game_links):
        try:
            games_info.append(get_info_box(link))
            if (i % 10 == 0):
                print(f'--Scraped {i} games--')

        except Exception as e:
            print(link)
            print(e)

    print(f'Scraping finished with {i} games')
    return games_info
    
games_info = scrape_game_company('https://en.wikipedia.org/wiki/List_of_Valve_games')
# Out:
# --Scraped 0 games--
# --Scraped 10 games--
# --Scraped 20 games--
# Scraping finished with 26 games

# %%
games_info
# Out:
# [{'Name': 'Half-Life',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_Cover_Art.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Sierra Studios',
#   'Writer(s)': 'Marc Laidlaw',
#   'Composer(s)': 'Kelly Bailey',
#   'Series': 'Half-Life',
#   'Engine': 'GoldSrc',
#   'Platform(s)': ['Windows', 'PlayStation 2', 'OS X', 'Linux'],
#   'Release': 'November 19, 1998',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life_(video_game)'},
#  {'Name': 'Team Fortress Classic',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Team_Fortress_Classic_box.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': ['Sierra Studios', 'Valve (digital)'],
#   'Designer(s)': ['John Cook', 'Robin Walker'],
#   'Engine': 'GoldSrc',
#   'Platform(s)': ['Microsoft Windows', 'OS X', 'Linux'],
#   'Release': 'April 7, 1999',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Team_Fortress_Classic'},
#  {'Name': 'Counter-Strike',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Counter-Strike_Box.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': ['Sierra Studios', 'Valve (digital)'],
#   'Designer(s)': ['Minh Le', 'Jess Cliffe'],
#   'Series': 'Counter-Strike',
#   'Engine': 'GoldSrc',
#   'Platform(s)': ['Windows', 'Xbox', 'OS X', 'Linux'],
#   'Release': 'November 18, 2003',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Counter-Strike_(video_game)'},
#  {'Name': 'Day of Defeat',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Day_of_Defeat_cover_art.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': ['Activision', 'Valve (digital)'],
#   'Composer(s)': 'Michael Gordon Shapiro',
#   'Engine': 'GoldSrc',
#   'Platform(s)': ['Microsoft Windows', 'OS X', 'Linux'],
#   'Release': 'May 6, 2003',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Day_of_Defeat'},
#  {'Name': 'Counter-Strike: Condition Zero',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:CZbox.jpg',
#   'Developer(s)': ['Ritual Entertainment', 'Turtle Rock Studios', 'Valve'],
#   'Publisher(s)': ['Sierra Entertainment', 'Valve (digital)'],
#   'Series': 'Counter-Strike',
#   'Engine': 'GoldSrc',
#   'Platform(s)': ['Windows', 'OS X', 'Linux'],
#   'Release': 'March 23, 2004',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Counter-Strike:_Condition_Zero'},
#  {'Name': 'Counter-Strike: Source',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Counter-Strike_Source_(box_art).jpg',
#   'Developer(s)': ['Valve', 'Turtle Rock Studios'],
#   'Publisher(s)': 'Valve',
#   'Series': 'Counter-Strike',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows', 'Mac OS X', 'Linux'],
#   'Release': 'October 7, 2004',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Counter-Strike:_Source'},
#  {'Name': 'Half-Life 2',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_2_cover.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': ['Valve', 'Sierra Entertainment(PC retail)'],
#   'Artist(s)': 'Viktor Antonov',
#   'Writer(s)': 'Marc Laidlaw',
#   'Composer(s)': 'Kelly Bailey',
#   'Series': 'Half-Life',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows',
#    'Xbox',
#    'Xbox 360',
#    'PlayStation 3',
#    'Mac OS X',
#    'Linux',
#    'Android'],
#   'Release': 'November 16, 2004',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life_2'},
#  {'Name': 'Half-Life 2: Deathmatch',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_2_Deathmatch_cover.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Series': 'Half-Life',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows', 'Mac OS X', 'Linux'],
#   'Release': 'November 30, 2004',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life_2:_Deathmatch'},
#  {'Name': 'Day of Defeat: Source',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:DODSourceCover.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Composer(s)': 'Dan Haigh',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows', 'Mac OS X', 'Linux'],
#   'Release': 'September 26, 2005',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Day_of_Defeat:_Source'},
#  {'Name': 'Half-Life 2: Lost Coast',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_2_Lost_Coast_header.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Series': 'Half-Life',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows', 'OS X', 'Linux'],
#   'Release': 'October 27, 2005',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life_2:_Lost_Coast'},
#  {'Name': 'Half-Life 2: Episode One',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_2_-_Episode_One.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Writer(s)': ['Erik Wolpaw', 'Chet Faliszek'],
#   'Composer(s)': 'Kelly Bailey',
#   'Series': 'Half-Life',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows',
#    'Xbox 360',
#    'PlayStation 3',
#    'Mac OS X',
#    'Linux',
#    'Android'],
#   'Release': 'June 1, 2006',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life_2:_Episode_One'},
#  {'Name': 'Half-Life 2: Episode Two',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_2_Episode_Two_title.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Writer(s)': ['Erik Wolpaw', 'Chet Faliszek'],
#   'Composer(s)': 'Kelly Bailey',
#   'Series': 'Half-Life',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows', 'PlayStation 3', 'Xbox 360', 'Mac OS X', 'Linux'],
#   'Release': 'October 10, 2007',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life_2:_Episode_Two'},
#  {'Name': 'Portal',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Portal_standalonebox.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': ['Valve', 'Microsoft Game Studios(Still Alive)'],
#   'Designer(s)': 'Kim Swift',
#   'Writer(s)': ['Erik Wolpaw', 'Chet Faliszek'],
#   'Composer(s)': ['Kelly Bailey', 'Mike Morasky'],
#   'Series': 'Portal',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows',
#    'PlayStation 3',
#    'Xbox 360',
#    'Mac OS X',
#    'Linux',
#    'Android',
#    'Nintendo Switch'],
#   'Release': 'October 10, 2007',
#   'Genre(s)': 'Puzzle-platform',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Portal_(video_game)'},
#  {'Name': 'Team Fortress 2',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Tf2_standalonebox.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Designer(s)': ['John Cook', 'Robin Walker'],
#   'Composer(s)': 'Mike Morasky',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows', 'Xbox 360', 'PlayStation 3', 'Mac OS X', 'Linux'],
#   'Release': 'October 10, 2007',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Team_Fortress_2'},
#  {'Name': 'The Orange Box',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Hltob-win-cover.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows',
#    'Xbox 360',
#    'PlayStation 3',
#    'Mac OS X',
#    'Linux'],
#   'Release': 'October 10, 2007',
#   'Genre(s)': 'Various',
#   'Mode(s)': ['Single player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/The_Orange_Box'},
#  {'Name': 'Left 4 Dead',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Left4Dead_Windows_cover.jpg',
#   'Developer(s)': 'Valve South',
#   'Publisher(s)': 'Valve',
#   'Designer(s)': 'Mike Booth',
#   'Writer(s)': 'Chet Faliszek',
#   'Composer(s)': 'Mike Morasky',
#   'Series': 'Left 4 Dead',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows', 'Xbox 360', 'Mac OS X'],
#   'Release': 'November 17, 2008',
#   'Genre(s)': ['First-person shooter', 'survival horror'],
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Left_4_Dead'},
#  {'Name': 'Left 4 Dead 2',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Left4Dead2.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Designer(s)': 'Michael Booth',
#   'Writer(s)': 'Chet Faliszek',
#   'Composer(s)': 'Mike Morasky',
#   'Series': 'Left 4 Dead',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows', 'Xbox 360', 'Mac OS X', 'Linux'],
#   'Release': 'November 17, 2009',
#   'Genre(s)': ['First-person shooter', 'survival horror'],
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Left_4_Dead_2'},
#  {'Name': 'Alien Swarm',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Alien_Swarm_Header.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Composer(s)': 'Mike Morasky',
#   'Engine': 'Source',
#   'Platform(s)': 'Microsoft Windows',
#   'Release': None,
#   'Genre(s)': 'Top-down shooter',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Alien_Swarm'},
#  {'Name': 'Portal 2',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Portal2cover.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Director(s)': 'Joshua Weier',
#   'Producer(s)': 'Gabe Newell',
#   'Artist(s)': ['Jeremy Bennett', 'Randy Lundeen'],
#   'Writer(s)': ['Erik Wolpaw', 'Jay Pinkerton', 'Chet Faliszek'],
#   'Composer(s)': 'Mike Morasky',
#   'Series': 'Portal',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows',
#    'Mac OS X',
#    'Linux',
#    'PlayStation 3',
#    'Xbox 360',
#    'Nintendo Switch'],
#   'Release': 'April 18, 2011',
#   'Genre(s)': 'Puzzle-platform',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Portal_2'},
#  {'Name': 'Counter-Strike: Global Offensive',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:CSGOcoverMarch2020.jpg',
#   'Developer(s)': ['Valve', 'Hidden Path Entertainment'],
#   'Publisher(s)': 'Valve',
#   'Composer(s)': 'Mike Morasky',
#   'Series': 'Counter-Strike',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows',
#    'macOS',
#    'Linux',
#    'PlayStation 3',
#    'Xbox 360'],
#   'Release': None,
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Counter-Strike:_Global_Offensive'},
#  {'Name': 'Dota 2',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Dota_2_(Steam_2019).jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Designer(s)': 'IceFrog',
#   'Writer(s)': ['Marc Laidlaw', 'Ted Kosmatka', 'Kris Katz'],
#   'Composer(s)': ['Jason Hayes', 'Tim Larkin'],
#   'Series': 'Dota',
#   'Engine': 'Source 2',
#   'Platform(s)': ['Microsoft Windows', 'Linux', 'OS X'],
#   'Release': 'July 9, 2013',
#   'Genre(s)': 'MOBA',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Dota_2'},
#  {'Name': 'The Lab',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:The_lab_logo.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Series': 'Portal',
#   'Engine': ['Unity', 'Source 2(Robot Repair)'],
#   'Platform(s)': 'Windows',
#   'Release': None,
#   'Genre(s)': 'Action',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/The_Lab_(video_game)'},
#  {'Name': 'Artifact',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Artifact_poster.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Director(s)': 'Brandon Reinhart',
#   'Designer(s)': 'Richard Garfield',
#   'Programmer(s)': ['Brad Muir', 'Jeep Barnett', 'Bruno Carlucci'],
#   'Writer(s)': 'Steve Jaros',
#   'Composer(s)': 'Tim Larkin',
#   'Series': 'Dota',
#   'Engine': 'Source 2',
#   'Platform(s)': ['Windows', 'macOS', 'Linux'],
#   'Release': None,
#   'Genre(s)': 'Digital collectible card game',
#   'Mode(s)': 'Multiplayer',
#   'Source': 'https://en.wikipedia.org/wiki/Artifact_(video_game)'},
#  {'Name': 'Dota Underlords',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Dota_Underlords_steam.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Series': 'Dota',
#   'Engine': 'Source 2',
#   'Platform(s)': ['Android', 'iOS', 'macOS', 'Microsoft Windows', 'Linux'],
#   'Release': None,
#   'Genre(s)': 'Auto battler',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Dota_Underlords'},
#  {'Name': 'Half-Life: Alyx',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Half-Life_Alyx_Cover_Art.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Writer(s)': ['Jay Pinkerton', 'Sean Vanaman', 'Erik Wolpaw', 'Jake Rodkin'],
#   'Composer(s)': 'Mike Morasky',
#   'Series': 'Half-Life',
#   'Engine': 'Source 2',
#   'Platform(s)': ['Windows', 'Linux'],
#   'Release': 'March 23, 2020',
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Half-Life:_Alyx'},
#  {'Name': 'Aperture Desk Job',
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Aperture_desk_job_logo.jpg',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': 'Valve',
#   'Composer(s)': ['Mike Morasky'],
#   'Series': 'Portal',
#   'Engine': 'Source 2',
#   'Platform(s)': ['Windows', 'Linux'],
#   'Release': None,
#   'Genre(s)': 'Action',
#   'Mode(s)': 'Single-player',
#   'Source': 'https://en.wikipedia.org/wiki/Aperture_Desk_Job'},
#  {'Name': "Garry's Mod",
#   'Image_link': 'https://en.wikipedia.org/wiki/File:Garry%27s_Mod_logo.svg',
#   'Developer(s)': 'Facepunch Studios',
#   'Publisher(s)': 'Valve',
#   'Designer(s)': 'Garry Newman',
#   'Programmer(s)': 'Garry Newman',
#   'Engine': 'Source',
#   'Platform(s)': ['Microsoft Windows', 'Mac OS X', 'Linux'],
#   'Release': None,
#   'Genre(s)': 'Sandbox',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Source': 'https://en.wikipedia.org/wiki/Garry%27s_Mod'}]

# %% [markdown]
# Things to clean:
# - Remove references [a] [1] etc
# - Convert from all li in one string to list of strings
# - In release, format from '\nNovember 19, 1998\n Windows' to 'November 19, 1998 (Windows)'

# %% [markdown]
# Tasks:
# - Scrape both websites
# - Convert to dictionary
# - Convert to pandas
# - Do some EDA
# - Make insights
