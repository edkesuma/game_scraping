# %% [markdown]
# ## EDA

# %% [markdown]
# Questions to answer:
# - Game company traits
# - Which gaming company has a better overall rating
# - Do ratings improve over time (release date of game)
# - Is this the death of one of the companies

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd

valve_df = pd.read_csv('valve_cleaned_csv.csv')
# Convert to datetime object
valve_df['Release'] = pd.to_datetime(valve_df['Release'], format = '%B %d, %Y')
valve_df.head()
# Out:
#                              Name  \
# 0                       Half-Life
# 1           Team Fortress Classic
# 2                  Counter-Strike
# 3                   Day of Defeat
# 4  Counter-Strike: Condition Zero
#
#                                           Image_link  \
# 0  https://en.wikipedia.org/wiki/File:Half-Life_C...
# 1  https://en.wikipedia.org/wiki/File:Team_Fortre...
# 2  https://en.wikipedia.org/wiki/File:Counter-Str...
# 3  https://en.wikipedia.org/wiki/File:Day_of_Defe...
# 4       https://en.wikipedia.org/wiki/File:CZbox.jpg
#
#                                         Developer(s)  \
# 0                                              Valve
# 1                                              Valve
# 2                                              Valve
# 3                                              Valve
# 4  ['Ritual Entertainment', 'Turtle Rock Studios'...
#
#                Publisher(s)     Writer(s)             Composer(s)  \
# 0            Sierra Studios  Marc Laidlaw            Kelly Bailey
# 1        ['Sierra Studios']           NaN                     NaN
# 2        ['Sierra Studios']           NaN                     NaN
# 3            ['Activision']           NaN  Michael Gordon Shapiro
# 4  ['Sierra Entertainment']           NaN                     NaN
#
#            Series   Engine                                    Platform(s)  \
# 0       Half-Life  GoldSrc  ['Windows', 'PlayStation 2', 'OS X', 'Linux']
# 1             NaN  GoldSrc         ['Microsoft Windows', 'OS X', 'Linux']
# 2  Counter-Strike  GoldSrc           ['Windows', 'Xbox', 'OS X', 'Linux']
# 3             NaN  GoldSrc         ['Microsoft Windows', 'OS X', 'Linux']
# 4  Counter-Strike  GoldSrc                   ['Windows', 'OS X', 'Linux']
#
#      Release              Genre(s)                           Mode(s)  \
# 0 1998-11-19  First-person shooter  ['Single-player', 'multiplayer']
# 1 1999-04-07  First-person shooter                       Multiplayer
# 2 2000-11-09  First-person shooter                       Multiplayer
# 3 2003-05-06  First-person shooter                       Multiplayer
# 4 2004-03-23  First-person shooter  ['Single-player', 'multiplayer']
#
#                                               Source  Metascore  User Score  \
# 0  https://en.wikipedia.org/wiki/Half-Life_(video...       96.0         9.1
# 1  https://en.wikipedia.org/wiki/Team_Fortress_Cl...        NaN         7.2
# 2  https://en.wikipedia.org/wiki/Counter-Strike_(...       88.0         9.2
# 3        https://en.wikipedia.org/wiki/Day_of_Defeat       79.0         9.0
# 4  https://en.wikipedia.org/wiki/Counter-Strike:_...       65.0         8.7
#
#                      Designer(s) Artist(s) Director(s) Producer(s)  \
# 0                            NaN       NaN         NaN         NaN
# 1  ['John Cook', 'Robin Walker']       NaN         NaN         NaN
# 2     ['Minh Le', 'Jess Cliffe']       NaN         NaN         NaN
# 3                            NaN       NaN         NaN         NaN
# 4                            NaN       NaN         NaN         NaN
#
#   Programmer(s)
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
blizzard_df = pd.read_csv('blizzard_cleaned_csv.csv')
# Convert to datetime object
blizzard_df['Release'] = pd.to_datetime(blizzard_df['Release'], format = '%B %d, %Y')
blizzard_df.head()
# Out:
#                                Name  \
# 0                        RPM Racing
# 1                  The Lost Vikings
# 2               Rock n' Roll Racing
# 3  The Death and Return of Superman
# 4                       Blackthorne
#
#                                           Image_link  \
# 0  https://en.wikipedia.org/wiki/File:RPM_Racing_...
# 1  https://en.wikipedia.org/wiki/File:The_Lost_Vi...
# 2  https://en.wikipedia.org/wiki/File:Rock_N%27_R...
# 3  https://en.wikipedia.org/wiki/File:The_Death_a...
# 4  https://en.wikipedia.org/wiki/File:Blackthorne...
#
#                             Developer(s)  \
# 0                      Silicon & Synapse
# 1                      Silicon & Synapse
# 2                 ['Software Creations']
# 3  ['Blizzard Entertainment', 'Sunsoft']
# 4                 Blizzard Entertainment
#
#                                         Publisher(s)  \
# 0  ['Interplay Productions', 'Victor Musical Indu...
# 1  ['Interplay Productions', 'T&E Soft', 'Blizzar...
# 2  ['Interplay Productions', 'Namco', 'Blizzard E...
# 3                                            Sunsoft
# 4                              Interplay Productions
#
#                                 Producer(s)  \
# 0                           Michael Quarles
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4  ['Ronald Millar Sr.', 'Matthew Findley']
#
#                                        Programmer(s)  \
# 0                                        Allen Adham
# 1                                                NaN
# 2      ['Bob Fitch', 'Patrick Wyatt', 'Ayman Adham']
# 3  ['James Edward Anhalt III', 'Allen Adham', 'Bo...
# 4              ['Frank Pearce Jr.', 'Patrick Wyatt']
#
#                                            Artist(s)  \
# 0                                         Rob Nesler
# 1                                                NaN
# 2  ['Samwise Didier', 'Ronald Millar Sr.', 'Joeyr...
# 3  ['Samwise Didier', 'David Berggren', 'Roman Ke...
# 4  ['Roman Kenney', 'Stuart Rose', 'Jason Magness...
#
#                               Composer(s)  \
# 0                  George Alistair Sanger
# 1                          Charles Deenen
# 2             Tim Follin and Geoff Follin
# 3  ['Michael Morhaime', 'Glenn Stafford']
# 4                          Glenn Stafford
#
#                                          Platform(s)    Release  \
# 0  ['Super NES', 'Windows', 'Switch', 'PlayStatio... 1992-03-19
# 1  ['Super Nintendo', 'Genesis', 'Amiga', 'MS-DOS... 1993-04-29
# 2  ['Super NES', 'Mega Drive/Genesis', 'Game Boy ... 1993-06-04
# 3                      ['Super NES', 'Sega Genesis']        NaT
# 4  ['SNES', 'MS-DOS', 'Sega 32X', 'Classic Mac OS... 2021-02-20
#
#           Genre(s)                           Mode(s)  \
# 0           Racing  ['Single-player', 'multiplayer']
# 1  Puzzle-platform  ['Single-player', 'cooperative']
# 2           Racing  ['Single-player', 'multiplayer']
# 3      Beat 'em up                     Single player
# 4         Platform                     Single-player
#
#                                               Source  Metascore  User Score  \
# 0           https://en.wikipedia.org/wiki/RPM_Racing        NaN         NaN
# 1     https://en.wikipedia.org/wiki/The_Lost_Vikings        NaN         NaN
# 2  https://en.wikipedia.org/wiki/Rock_n%27_Roll_R...        NaN         NaN
# 3  https://en.wikipedia.org/wiki/The_Death_and_Re...        NaN         NaN
# 4          https://en.wikipedia.org/wiki/Blackthorne        NaN         NaN
#
#          Designer(s)                                          Writer(s)  \
# 0                NaN                                                NaN
# 1         Ron Millar                                                NaN
# 2       Alan Pavlish                                                NaN
# 3      Dan MacArthur                                                NaN
# 4  Ronald Millar Sr.  ['Micky Neilson', 'Ronald Millar Sr.', 'Frank ...
#
#   Director(s) Series Engine
# 0         NaN    NaN    NaN
# 1         NaN    NaN    NaN
# 2         NaN    NaN    NaN
# 3         NaN    NaN    NaN
# 4         NaN    NaN    NaN

# %% [markdown]
# ### Game company traits

# %%
# Top 3 genres of games made by each company
valve_df['Genre(s)'].value_counts().head(3)
# Out:
# First-person shooter    15
# Action                   2
# Puzzle-platform          2
# Name: Genre(s), dtype: int64

# %%
blizzard_df['Genre(s)'].value_counts().head(3)
# Out:
# Real-time strategy      5
# First-person shooter    2
# Racing                  2
# Name: Genre(s), dtype: int64

# %%
# Top combinations of platforms games are released on by game company
valve_df['Platform(s)'].value_counts().head(3)
# Out:
# ['Microsoft Windows', 'OS X', 'Linux']        3
# ['Microsoft Windows', 'Mac OS X', 'Linux']    3
# ['Windows', 'Linux']                          2
# Name: Platform(s), dtype: int64

# %%
blizzard_df['Platform(s)'].value_counts().head(3)
# Out:
# ['Microsoft Windows', 'macOS']                                           3
# ['Microsoft Windows', 'PlayStation 4', 'Xbox One', 'Nintendo Switch']    2
# ['Microsoft Windows', 'Classic Mac OS', 'Mac OS X']                      1
# Name: Platform(s), dtype: int64

# %%
# Top combination of modes by each game company
valve_df['Mode(s)'].value_counts().head(3)
# Out:
# Multiplayer                         9
# ['Single-player', 'multiplayer']    9
# Single-player                       8
# Name: Mode(s), dtype: int64

# %%
blizzard_df['Mode(s)'].value_counts().head(3)
# Out:
# ['Single-player', 'multiplayer']    12
# Multiplayer                          6
# ['Single-player', 'cooperative']     1
# Name: Mode(s), dtype: int64

# %% [markdown]
# Insights:
# - Genre:
#     - Valve mainly creates FPS games
#     - Blizzard mainly creates RTS games
# - Platform:
#     - Valve mainly releases games on platforms with the combination [Windows, macOS, Linux]
#     - Blizzard mainly releases on the platform combination [Windows, macOS]
# - Mode:
#     - Valve games have an even spread between strictly single-player/multiplayer or both
#     - Blizzard games mainly have both modes, less strictly multiplayer games and only one strictly single-player game

# %% [markdown]
# ### Which company has better ratings?

# %% [markdown]
# #### Clustering

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

score_data_valve = valve_df[['Name', 'Metascore', 'User Score', 'Release']]
score_data_blizzard = blizzard_df[['Name', 'Metascore', 'User Score', 'Release']]

score_data_valve['Game Company'] = 'Valve'
score_data_blizzard['Game Company'] = 'Blizzard'
score_data = pd.concat([score_data_valve, score_data_blizzard], ignore_index=True)
score_data.tail()
# Out:
#                    Name  Metascore  User Score    Release Game Company
# 44  Heroes of the Storm       86.0         6.3 2015-06-02     Blizzard
# 45            Overwatch       91.0         6.4 2016-05-24     Blizzard
# 46      Diablo Immortal        NaN         NaN 2022-06-02     Blizzard
# 47          Overwatch 2        NaN         NaN        NaT     Blizzard
# 48            Diablo IV        NaN         NaN        NaT     Blizzard

# %%
# drop if there's more than 1 NaN in the subset (i.e. both metascore and userscore are NaN)
score_data = score_data.dropna(subset=['Metascore', 'User Score'], thresh=1)
score_data = score_data.reset_index(drop=True)
score_data.tail()
# Out:
#                                Name  Metascore  User Score    Release  \
# 33   StarCraft II: Wings of Liberty       93.0         8.3 2010-07-27
# 34                       Diablo III       88.0         4.1 2012-05-15
# 35  Hearthstone: Heroes of Warcraft       88.0         5.7 2014-03-11
# 36              Heroes of the Storm       86.0         6.3 2015-06-02
# 37                        Overwatch       91.0         6.4 2016-05-24
#
#    Game Company
# 33     Blizzard
# 34     Blizzard
# 35     Blizzard
# 36     Blizzard
# 37     Blizzard

# %%
# Impute missing metascores with user scores
score_data['Metascore filled'] = [uscore * 10 if np.isnan(score_data['Metascore'][i]) 
                    else score_data['Metascore'][i] for i, uscore in enumerate(score_data['User Score'])]

# %%
data_for_cluster = score_data[['Metascore filled', 'User Score']]

# create clusters based on metascore and user score
kmeans = KMeans(n_clusters=4, random_state=0).fit(data_for_cluster)
clusters = kmeans.predict(data_for_cluster)
score_data['Cluster'] = clusters
score_data
# Out:
#                                 Name  Metascore  User Score    Release  \
# 0                          Half-Life       96.0         9.1 1998-11-19
# 1              Team Fortress Classic        NaN         7.2 1999-04-07
# 2                     Counter-Strike       88.0         9.2 2000-11-09
# 3                      Day of Defeat       79.0         9.0 2003-05-06
# 4     Counter-Strike: Condition Zero       65.0         8.7 2004-03-23
# 5             Counter-Strike: Source       88.0         8.9 2004-10-07
# 6                        Half-Life 2       96.0         9.2 2004-11-16
# 7            Half-Life 2: Deathmatch        NaN         7.3 2004-11-30
# 8              Day of Defeat: Source       80.0         9.0 2005-09-26
# 9            Half-Life 2: Lost Coast        NaN         7.9 2005-10-27
# 10          Half-Life 2: Episode One       87.0         8.7 2006-06-01
# 11          Half-Life 2: Episode Two       90.0         9.2 2007-10-10
# 12                            Portal       90.0         9.2 2007-10-10
# 13                   Team Fortress 2       92.0         9.0 2007-10-10
# 14                    The Orange Box       96.0         9.1 2007-10-10
# 15                       Left 4 Dead       89.0         9.0 2008-11-17
# 16                     Left 4 Dead 2       89.0         8.4 2009-11-17
# 17                       Alien Swarm       77.0         8.2 2010-07-19
# 18                          Portal 2       95.0         9.1 2011-04-18
# 19  Counter-Strike: Global Offensive       83.0         7.3 2012-08-21
# 20                            Dota 2       90.0         6.5 2013-07-09
# 21                           The Lab        NaN         8.5 2016-04-05
# 22                          Artifact       76.0         2.2 2018-11-28
# 23                   Dota Underlords        NaN         7.4 2020-02-25
# 24                   Half-Life: Alyx       93.0         9.2 2020-03-23
# 25                 Aperture Desk Job        NaN         8.6 2022-03-01
# 26                       Garry's Mod        NaN         8.9 2006-11-29
# 27    Warcraft II: Tides of Darkness        NaN         9.0 1995-12-09
# 28                            Diablo       94.0         8.6 1997-01-03
# 29                         StarCraft       88.0         9.1 1998-03-31
# 30                         Diablo II       88.0         8.7 2000-06-29
# 31      Warcraft III: Reign of Chaos       92.0         9.2 2002-07-03
# 32                 World of Warcraft       93.0         7.4 2004-11-23
# 33    StarCraft II: Wings of Liberty       93.0         8.3 2010-07-27
# 34                        Diablo III       88.0         4.1 2012-05-15
# 35   Hearthstone: Heroes of Warcraft       88.0         5.7 2014-03-11
# 36               Heroes of the Storm       86.0         6.3 2015-06-02
# 37                         Overwatch       91.0         6.4 2016-05-24
#
#    Game Company  Metascore filled  Cluster
# 0         Valve              96.0        3
# 1         Valve              72.0        0
# 2         Valve              88.0        1
# 3         Valve              79.0        2
# 4         Valve              65.0        0
# 5         Valve              88.0        1
# 6         Valve              96.0        3
# 7         Valve              73.0        0
# 8         Valve              80.0        2
# 9         Valve              79.0        2
# 10        Valve              87.0        1
# 11        Valve              90.0        1
# 12        Valve              90.0        1
# 13        Valve              92.0        3
# 14        Valve              96.0        3
# 15        Valve              89.0        1
# 16        Valve              89.0        1
# 17        Valve              77.0        2
# 18        Valve              95.0        3
# 19        Valve              83.0        2
# 20        Valve              90.0        1
# 21        Valve              85.0        1
# 22        Valve              76.0        0
# 23        Valve              74.0        0
# 24        Valve              93.0        3
# 25        Valve              86.0        1
# 26        Valve              89.0        1
# 27     Blizzard              90.0        1
# 28     Blizzard              94.0        3
# 29     Blizzard              88.0        1
# 30     Blizzard              88.0        1
# 31     Blizzard              92.0        3
# 32     Blizzard              93.0        3
# 33     Blizzard              93.0        3
# 34     Blizzard              88.0        1
# 35     Blizzard              88.0        1
# 36     Blizzard              86.0        1
# 37     Blizzard              91.0        1

# %%
valve_games = score_data[score_data['Game Company'] == 'Valve']
blizzard_games = score_data[score_data['Game Company'] == 'Blizzard']
valve_games.head()
# Out:
#                              Name  Metascore  User Score    Release  \
# 0                       Half-Life       96.0         9.1 1998-11-19
# 1           Team Fortress Classic        NaN         7.2 1999-04-07
# 2                  Counter-Strike       88.0         9.2 2000-11-09
# 3                   Day of Defeat       79.0         9.0 2003-05-06
# 4  Counter-Strike: Condition Zero       65.0         8.7 2004-03-23
#
#   Game Company  Metascore filled  Cluster
# 0        Valve              96.0        3
# 1        Valve              72.0        0
# 2        Valve              88.0        1
# 3        Valve              79.0        2
# 4        Valve              65.0        0

# %%
# Clustered scores (not separated by game company)
plt.scatter(score_data['Metascore filled'], score_data['User Score'], c=score_data['Cluster'], cmap='rainbow')
plt.xlabel('Metascore')
plt.ylabel('Userscore')
plt.show()

# %%
# Clustered scores (marker separated by game company)
plt.scatter(valve_games['Metascore filled'][valve_games['Cluster']==0],
           valve_games['User Score'][valve_games['Cluster']==0], marker='^', 
            c='purple')

plt.scatter(valve_games['Metascore filled'][valve_games['Cluster']==1],
           valve_games['User Score'][valve_games['Cluster']==1], marker='^', 
            c='turquoise')

plt.scatter(valve_games['Metascore filled'][valve_games['Cluster']==2],
           valve_games['User Score'][valve_games['Cluster']==2], marker='^', 
            c='olive')

plt.scatter(valve_games['Metascore filled'][valve_games['Cluster']==3],
           valve_games['User Score'][valve_games['Cluster']==3], marker='^', 
            c='red')


plt.scatter(blizzard_games['Metascore filled'][blizzard_games['Cluster']==0],
           blizzard_games['User Score'][blizzard_games['Cluster']==0], marker='o', 
            c='purple')

plt.scatter(blizzard_games['Metascore filled'][blizzard_games['Cluster']==1],
           blizzard_games['User Score'][blizzard_games['Cluster']==1], marker='o', 
            c='turquoise')

plt.scatter(blizzard_games['Metascore filled'][blizzard_games['Cluster']==2],
           blizzard_games['User Score'][blizzard_games['Cluster']==2], marker='o', 
            c='olive')

plt.scatter(blizzard_games['Metascore filled'][blizzard_games['Cluster']==3],
           blizzard_games['User Score'][blizzard_games['Cluster']==3], marker='o', 
            c='red')

plt.xlabel('Metascore')
plt.ylabel('User score')
plt.legend(['Valve C1', 'Valve C2', 'Valve C3', 'Valve C4', 'Blizzard C1', 'Blizzard C2', 'Blizzard C3', 'Blizzard C4'], loc='lower left')
plt.show()

# %% [markdown]
# #### Comparison by Mean/Median Scores

# %%
valve_games['Metascore filled'].mean(), blizzard_games['Metascore filled'].mean()
# Out:
# (85.07407407407408, 90.0909090909091)

# %%
valve_games['User Score'].mean(), blizzard_games['User Score'].mean()
# Out:
# (8.296296296296296, 7.527272727272728)

# %% [markdown]
# Insights:
# - Based on Clustering:
#     - Valve game ratings in all clusters from low metascore, user score to high metascore, user score
#     - Blizzard games exist in cluster 2 and 3 where games have consistently high metascore with middle to high user score
# - Based on Mean/Median:
#     - Valve games have a higher average user score than Blizzard
#     - Blizzard games have a higher metascore than Valve
# - Reasoning:
#     - Metascores are only influenced by a select group of renowned critics and usually given to a game upon release
#     - User scores can be from anyone on the internet
# - Conclusion:
#     - Blizzard games may be better on release but poorly maintained: causing user scores to go down over time
#     - Blizzard games may have better connections with critics to drive metascores up (controversial)
#     - Valve games may be more consistent in maintaining their games to keep user scores high

# %% [markdown]
# ### Do ratings improve over time?

# %%
# Interesting - 4 games were released in 10/10/2007
valve_games.sort_values(by='Release',inplace=True)
valve_games
# Out:
#                                 Name  Metascore  User Score    Release  \
# 0                          Half-Life       96.0         9.1 1998-11-19
# 1              Team Fortress Classic        NaN         7.2 1999-04-07
# 2                     Counter-Strike       88.0         9.2 2000-11-09
# 3                      Day of Defeat       79.0         9.0 2003-05-06
# 4     Counter-Strike: Condition Zero       65.0         8.7 2004-03-23
# 5             Counter-Strike: Source       88.0         8.9 2004-10-07
# 6                        Half-Life 2       96.0         9.2 2004-11-16
# 7            Half-Life 2: Deathmatch        NaN         7.3 2004-11-30
# 8              Day of Defeat: Source       80.0         9.0 2005-09-26
# 9            Half-Life 2: Lost Coast        NaN         7.9 2005-10-27
# 10          Half-Life 2: Episode One       87.0         8.7 2006-06-01
# 26                       Garry's Mod        NaN         8.9 2006-11-29
# 12                            Portal       90.0         9.2 2007-10-10
# 14                    The Orange Box       96.0         9.1 2007-10-10
# 11          Half-Life 2: Episode Two       90.0         9.2 2007-10-10
# 13                   Team Fortress 2       92.0         9.0 2007-10-10
# 15                       Left 4 Dead       89.0         9.0 2008-11-17
# 16                     Left 4 Dead 2       89.0         8.4 2009-11-17
# 17                       Alien Swarm       77.0         8.2 2010-07-19
# 18                          Portal 2       95.0         9.1 2011-04-18
# 19  Counter-Strike: Global Offensive       83.0         7.3 2012-08-21
# 20                            Dota 2       90.0         6.5 2013-07-09
# 21                           The Lab        NaN         8.5 2016-04-05
# 22                          Artifact       76.0         2.2 2018-11-28
# 23                   Dota Underlords        NaN         7.4 2020-02-25
# 24                   Half-Life: Alyx       93.0         9.2 2020-03-23
# 25                 Aperture Desk Job        NaN         8.6 2022-03-01
#
#    Game Company  Metascore filled  Cluster
# 0         Valve              96.0        3
# 1         Valve              72.0        0
# 2         Valve              88.0        1
# 3         Valve              79.0        2
# 4         Valve              65.0        0
# 5         Valve              88.0        1
# 6         Valve              96.0        3
# 7         Valve              73.0        0
# 8         Valve              80.0        2
# 9         Valve              79.0        2
# 10        Valve              87.0        1
# 26        Valve              89.0        1
# 12        Valve              90.0        1
# 14        Valve              96.0        3
# 11        Valve              90.0        1
# 13        Valve              92.0        3
# 15        Valve              89.0        1
# 16        Valve              89.0        1
# 17        Valve              77.0        2
# 18        Valve              95.0        3
# 19        Valve              83.0        2
# 20        Valve              90.0        1
# 21        Valve              85.0        1
# 22        Valve              76.0        0
# 23        Valve              74.0        0
# 24        Valve              93.0        3
# 25        Valve              86.0        1

# %%
blizzard_games.sort_values(by='Release', inplace=True)
blizzard_games
# Out:
#                                Name  Metascore  User Score    Release  \
# 27   Warcraft II: Tides of Darkness        NaN         9.0 1995-12-09
# 28                           Diablo       94.0         8.6 1997-01-03
# 29                        StarCraft       88.0         9.1 1998-03-31
# 30                        Diablo II       88.0         8.7 2000-06-29
# 31     Warcraft III: Reign of Chaos       92.0         9.2 2002-07-03
# 32                World of Warcraft       93.0         7.4 2004-11-23
# 33   StarCraft II: Wings of Liberty       93.0         8.3 2010-07-27
# 34                       Diablo III       88.0         4.1 2012-05-15
# 35  Hearthstone: Heroes of Warcraft       88.0         5.7 2014-03-11
# 36              Heroes of the Storm       86.0         6.3 2015-06-02
# 37                        Overwatch       91.0         6.4 2016-05-24
#
#    Game Company  Metascore filled  Cluster
# 27     Blizzard              90.0        1
# 28     Blizzard              94.0        3
# 29     Blizzard              88.0        1
# 30     Blizzard              88.0        1
# 31     Blizzard              92.0        3
# 32     Blizzard              93.0        3
# 33     Blizzard              93.0        3
# 34     Blizzard              88.0        1
# 35     Blizzard              88.0        1
# 36     Blizzard              86.0        1
# 37     Blizzard              91.0        1

# %%
plt.figure(figsize=[10,5])
plt.plot(valve_games['Release'], valve_games['Metascore filled'])
plt.plot(valve_games['Release'], valve_games['User Score']*10, color='green')
plt.title('Valve Game Ratings Over Time', fontsize=15)
plt.xlabel('Release Date')
plt.ylabel('Scores')
plt.legend(['Metascore', 'User Score'])
# rotates xlabels by 30 degrees
plt.xticks(rotation=30, ha='right')
plt.show()

# %%
plt.figure(figsize=[10,5])
plt.plot(blizzard_games['Release'], blizzard_games['Metascore filled'])
plt.plot(blizzard_games['Release'], blizzard_games['User Score']*10, color='green')
plt.title('Blizzard Game Ratings Over Time', fontsize=15)
plt.xlabel('Release Date')
plt.ylabel('Scores')
plt.legend(['Metascore', 'User Score'])
# rotates xlabels by 30 degrees
plt.xticks(rotation=30, ha='right')
plt.show()

# %% [markdown]
# Insights:
# - Valve ratings:
#     - User score and metascore have been fairly consistent
#     - Except for 2 failed games around 2014 and 2019 where user score plummeted
# - Blizzard ratings:
#     - User score and metascore were consistent up until 2004
#     - Then user score started being consistently lower than metascore (with increasing gaps)

# %% [markdown]
# ### Is this the end of Blizzard?

# %%
from PIL import Image
import requests

plt.figure(figsize=[10,10])
# Source: https://gamingbolt.com/blizzard-has-lost-29-of-its-playerbase-in-the-last-3-years
url='https://i.postimg.cc/c4vjq081/blizzard-playerbase.jpg'
im = requests.get(url, stream=True).raw
image = Image.open(im)
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 1279.5, 210.5, -0.5)

# %% [markdown]
# Well..
# - Blizzard has declining user scores
# - Its good titles like WoW are getting old
# - Hasn't released a new game since 2016
#
# However..
# - They will release two new games soon
# - Revenues are up 7% despite the lower playerbase

# %% [markdown]
# ### Extra: Word cloud

# %%
from wordcloud import WordCloud, ImageColorGenerator

# get mask
url='https://www.pcgamesn.com/wp-content/uploads/2018/09/steam-logo.jpg'
im = requests.get(url, stream=True).raw
image = Image.open(im)
steam_mask = np.array(image)

plt.figure(figsize=[10,10])
plt.subplot(2,1,1)
# show original image
plt.imshow(image)
plt.axis("off")

# generate word cloud
wc = WordCloud(background_color="white", max_words=100, mask=steam_mask,
               max_font_size=90, random_state=42)
wc.generate(' '.join(valve_games['Name']))

# create coloring from image
image_colors = ImageColorGenerator(steam_mask)
plt.figure(figsize=[10,10])
plt.subplot(2,1,2)
# show wordcloud
plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")

plt.show()
